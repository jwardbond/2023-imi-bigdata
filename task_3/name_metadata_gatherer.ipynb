# %%
import pandas as pd
import json

# %%
names = pd.read_parquet('matches.parquet')
names = names[names['score'] >= 90]
names = names.drop_duplicates(['name', 'match'])

# %%
names
# Out:
#                   name               match  score       ratio source
# 28       terry daniels        daniel terry     96  fuzz.ratio
# 34         james lewis         james lewis    100  fuzz.ratio
# 39     richard austin.      richard austin    100  fuzz.ratio
# 54     jeffrey h. wood     dr.jeffrey wood     90  fuzz.ratio
# 55    edward o. walker       edward walker     93  fuzz.ratio
# ...                ...                 ...    ...         ...    ...
# 1188  gérald thériault    gérard thériault     93  fuzz.ratio
# 1196         kiem tran            kim tran     94  fuzz.ratio
# 1200        liang chen          chen liang    100  fuzz.ratio
# 1236   brad stephenson  brandon stephenson     91  fuzz.ratio
# 1240        brian hart          brian hart    100  fuzz.ratio
#
# [87 rows x 5 columns]

# %%
scraped = pd.read_csv('incidents_scraped.csv')

# %%
# check articles
results = {}
for index, row in names.iterrows():
    hits = scraped[scraped['scrape_text'].str.contains(row['name'], case=False, na=False)]
    if not hits.empty:

        results[row['match']] = {}

        results[row['match']]['case_name'] = row['name']
        results[row['match']]['case_name_score'] = row['score']

        # context
        start_index = hits.iloc[0]['scrape_text'].lower().find(row['name'])
        start = max(start_index - 100, 0) 
        end = min(start_index + len(row['name']) + 100, len(hits.iloc[0]['scrape_text']))
        results[row['match']]['case_name_context'] = hits.iloc[0]['scrape_text'][start:end]

        results[row['match']]['sources'] = hits['Primary Source'].to_list()

# %%
results
# Out:
# {'daniel terry': {'case_name': 'terry daniels',
#   'case_name_score': 96,
#   'case_name_context': '. Eagle parts trafficking case hears sentencing arguments Visit CBC Aboriginal for more top stories Terry Daniels and her brother Harlin were fined a combined $8,500 — $7,000 and $1,500, respectively — for illegal',
#   'sources': ['https://www.cbc.ca/news/canada/calgary/eagle-parts-trafficking-case-nets-stoney-nakoda-siblings-8-5k-fine-1.2666372']},
#  'james lewis': {'case_name': 'james lewis',
#   'case_name_score': 100,
#   'case_name_context': '18 Share Facebook X LinkedIn Email For Immediate Release Office of Public Affairs Joseph Kelley and James Lewis were each indicted in Newark, New Jersey, with crimes related to illegally trafficking juvenile Ame',
#   'sources': ['https://www.justice.gov/opa/pr/two-men-indicted-illegally-trafficking-american-eels']},
#  'richard austin': {'case_name': 'richard d. austin',
#   'case_name_score': 93,
#   'case_name_context': 'ay, October 26, 2017 Share Facebook X LinkedIn Email For Immediate Release Office of Public Affairs Richard D. Austin was sentenced to 24 months’ imprisonment yesterday for trafficking juvenile American eels (also cal',
#   'sources': ['https://www.justice.gov/opa/pr/maine-fisherman-sentenced-illegally-trafficking-american-eels']},
#  'dr.jeffrey wood': {'case_name': 'jeffrey h. wood',
#   'case_name_score': 90,
#   'case_name_context': 'f the indictment and court appearance were was announced today by Acting Assistant Attorney General Jeffrey H. Wood of the Justice Department’s Environment and Natural Resources Division and Acting U.S. Attorney Wil',
#   'sources': ['https://www.justice.gov/opa/pr/alleged-head-wildlife-smuggling-ring-extradited-australia',
#    'https://www.justice.gov/opa/pr/maine-fisherman-sentenced-illegally-trafficking-american-eels',
#    'https://www.justice.gov/opa/pr/owner-arecibo-aquarium-business-pleads-guilty-two-federal-lacey-act-felonies-illicit',
#    'https://www.justice.gov/usao-edtx/pr/jefferson-county-man-convicted-killing-whooping-cranes-headed-prison-after-violating',
#    'https://www.justice.gov/opa/pr/maine-fisherman-sentenced-illegally-trafficking-american-eels-0',
#    'https://www.justice.gov/opa/pr/irish-national-sentenced-18-months-prison-trafficking-endangered-rhinoceros-horn-libation-cup',
#    'https://www.justice.gov/opa/pr/two-men-indicted-illegally-trafficking-american-eels',
#    'https://www.justice.gov/opa/pr/connecticut-man-pleads-guilty-trafficking-endangered-sperm-whale-teeth',
#    'https://www.justice.gov/opa/pr/pennsylvania-man-indicted-trafficking-turtles']},
#  'edward walker': {'case_name': 'edward o. walker',
#   'case_name_score': 93,
#   'case_name_context': 'vestigated by the U.S. Fish and Wildlife Service and prosecuted by Assistant United States Attorney Edward O. Walker. # # # This news release, as well as additional information about the office of the United States A',
#   'sources': ['https://www.justice.gov/usao-edar/pr/conway-man-pleads-guilty-importation-and-possession-illegally-taken-wildlife',
#    'https://www.justice.gov/usao-edar/pr/conway-man-pleads-guilty-importation-and-possession-illegally-taken-wildlife',
#    'https://www.justice.gov/usao-edar/pr/conway-man-pleads-guilty-importation-and-possession-illegally-taken-wildlife',
#    'https://www.justice.gov/usao-edar/pr/conway-man-pleads-guilty-importation-and-possession-illegally-taken-wildlife']},
#  'gilles allain': {'case_name': 'gilles allain',
#   'case_name_score': 100,
#   'case_name_context': 'a\xa0nine-month investigation known as Operation Meat Bag, the provincial government announced Monday. Gilles Allain pleaded guilty to 27 violations of the Fish and Wildlife Act:\xa012 counts of hunting moose out of sea',
#   'sources': ['https://www.cbc.ca/amp/1.5389834']},
#  'alejandro martin': {'case_name': 'alejandro martinez',
#   'case_name_score': 94,
#   'case_name_context': "rld in search of big game. The group included Martinez's two sons, Hector Armando Martinez, 38, and Alejandro Martinez, 35 -- also from Monterey and who work for their father's property development firm -- and Martinez",
#   'sources': ['https://www.ctvnews.ca/canada/winnipeg-judge-fines-mexican-hunters-for-trying-to-export-polar-bear-hides-1.1226847']},
#  'gabrielle harper': {'case_name': 'gabriel harper',
#   'case_name_score': 93,
#   'case_name_context': ' at JFK in April this year after smuggling 26 finches in hair curlers and stuffing them into socks. Gabriel Harper of the US Fish and Wildlife Service said that the birds are used in singing competitions, where win',
#   'sources': ['https://www.independent.co.uk/travel/news-and-advice/finches-jfk-airport-bird-smuggling-live-birds-us-customs-tsa-a8681941.html',
#    'http://demerarawaves.com/2018/04/04/two-arrested-at-jfk-airport-for-smuggling-birds-from-guyana/']},
#  'james hayes': {'case_name': 'james t. hayes',
#   'case_name_score': 92,
#   'case_name_context': 'on putting them out of business,” said ICE Homeland Security Investigations Special Agent in Charge James T. Hayes.  “We will continue using all our resources to identify and apprehend those who exploit threatened ',
#   'sources': ['https://www.justice.gov/archive/usao/nye/pr/2010/2010dec15c.html']},
#  'christy ford': {'case_name': 'chris ford',
#   'case_name_score': 91,
#   'case_name_context': 'il Share on Facebook Share on X Share on LinkedIn Print Share via Text Message Conservation officer Chris Ford investigates a cow moose poaching complaint on traditional ʔEsdilagh territory at Alexandria last w',
#   'sources': ['https://www.coastmountainnews.com/news/first-nations-community-supports-charges-in-cariboo-region-cow-moose-poaching-case/#']},
#  'jeffery richards': {'case_name': 'jeff richards',
#   'case_name_score': 90,
#   'case_name_context': '\t\t38 Sat 63/\n\t\t\t\t\t42 Cedar City man receives fine, probation in trophy elk poaching case Written by Jeff Richards January 20, 2021 Alleged evidence of illegal poaching at a residence in Cedar City, Utah, date not ',
#   'sources': ['https://www.stgeorgeutah.com/news/archive/2021/01/20/jmr-cedar-city-man-receives-fine-probation-in-trophy-elk-poaching-case/#.YArlqv1Kg2w']},
#  'aaron jones': {'case_name': 'aaron jones',
#   'case_name_score': 100,
#   'case_name_context': 'nd the Ohio Attorney General’s Office. The eight people charged face a combined 91 criminal counts. Aaron Jones, 32, of Thurman, Brittney Marcum, 31, of Thurman, Randy Jones Jr., 64, of Thurman, Charlotte Jones,',
#   'sources': ['https://www.wsaz.com/2021/10/21/eight-indicted-stealing-deer-meat-illegally-poaching-white-tailed-deer/']},
#  'maria nguyen': {'case_name': 'mai nguyen',
#   'case_name_score': 91,
#   'case_name_context': '.S.\xa0 Charges were filed against Jimmy Kha, the owner of Win Lee Corporation; his son Felix Kha; and Mai Nguyen, the owner of a nail salon where packages containing rhinoceros horns were being mailed.\xa0 One of th',
#   'sources': ['http://www.justice.gov/opa/pr/2012/February/12-enrd-246.html']},
#  'charlotte jones': {'case_name': 'charlotte jones',
#   'case_name_score': 100,
#   'case_name_context': 'nts. Aaron Jones, 32, of Thurman, Brittney Marcum, 31, of Thurman, Randy Jones Jr., 64, of Thurman, Charlotte Jones, 63, of Thurman, James Copley, 58, of Thurman, Justin Wells, of Thurman, William Gilbert, 27, of Th',
#   'sources': ['https://www.wsaz.com/2021/10/21/eight-indicted-stealing-deer-meat-illegally-poaching-white-tailed-deer/']},
#  'qin xiao hong': {'case_name': 'xiao dong qin',
#   'case_name_score': 92,
#   'case_name_context': 'tles were purchased in the U.S. and smuggled via U.S. mail and commercial airline flights to China. Xiao Dong Qin, 34, a resident of Shanghai, China, pleaded guilty to one count of conspiring to smuggle goods from',
#   'sources': ['https://www.justice.gov/usao-or/pr/chinese-national-pleads-guilty-smuggling-more-300-endangered-and-vulnerable-turtles-us',
#    'https://www.justice.gov/usao-or/pr/california-man-sentenced-role-scheme-smuggle-endangered-and-vulnerable-turtles-us-china']},
#  'bryan blair': {'case_name': 'ryan blair',
#   'case_name_score': 95,
#   'case_name_context': 'dividuals for antler hunting in the Gros Ventre drainage north of Jackson during the closed season. Ryan Blair, of Jackson, pleaded guilty to the offense, paid a $435 fine and lost his hunting and fishing privi',
#   'sources': ['https://www.einnews.com/pr_news/519511300/antler-poachers-sentenced',
#    'https://www.einnews.com/pr_news/519511300/antler-poachers-sentenced',
#    'https://www.einnews.com/pr_news/519511300/antler-poachers-sentenced']},
#  'zhou jin feng': {'case_name': 'jin zhao feng',
#   'case_name_score': 92,
#   'case_name_context': 'd prosecute those involved in the black market trade of endangered rhinoceros horn. In Los Angeles, Jin Zhao Feng, a Chinese national who allegedly oversaw the shipment of at least dozens of rhino horns from the U',
#   'sources': ['http://www.justice.gov/opa/pr/2012/February/12-enrd-246.html']},
#  'olivia terrance': {'case_name': 'olivia terrance',
#   'case_name_score': 100,
#   'case_name_context': ' the U.S. has been sentenced to 18 months in jail. U.S. Attorney Richard Hartunian says 28-year-old Olivia Terrance of Hogansburg pleaded guilty to smuggling charges in April. Hartunian says Terrance participated in',
#   'sources': ['http://globalnews.ca/news/799681/ny-woman-sentenced-for-smuggling-turtles-and-reptiles-into-canada-by-boat/']},
#  'kara rodriguez': {'case_name': 'karla rodríguez',
#   'case_name_score': 93,
#   'case_name_context': 'uría Federal de Protección al Ambiente Foto: Archivo / EL UNIVERSAL Sociedad | 23/12/2019 | 20:10 | Karla Rodríguez | Actualizada 20:10 Redacción El Universal Ver perfil Más Información Sasha Montenegro: Así se mani',
#   'sources': ['https://www.eluniversal.com.mx/nacion/sociedad/vinculan-proceso-dos-personas-por-posesion-de-buches-de-totoaba']},
#  'jerome nicholson': {'case_name': 'joe nicholson',
#   'case_name_score': 90,
#   'case_name_context': ' the interests of legal and ethical hunters and outfitters in the state,” said CPW Wildlife Officer Joe Nicholson, who worked on the case. “That is really important. We have a strong heritage in Colorado of huntin',
#   'sources': ['https://www.thedenverchannel.com/news/crime/jefferson-county-man-convicted-for-illegally-hunting-selling-mountain-lion']},
#  'kevin ryan': {'case_name': 'kevin tran',
#   'case_name_score': 90,
#   'case_name_context': 'in the world. "Which is why they are protected," said\xa0Henderson. But the CDFW says, just weeks ago, Kevin Tran of Tracy caught one in Clifton Court Forebay and took it home. The CDFW was\xa0notified by witnesses w',
#   'sources': ['https://sacramento.cbslocal.com/2022/02/10/endangered-sturgeon-poached-from-tracy-waterway/']},
#  'patrick sherman': {'case_name': 'patrick sheridan',
#   'case_name_score': 90,
#   'case_name_context': 'to a year in prison for trafficking in endangered rhinoceros horns, the US Justice Department said. Patrick Sheridan, who was extradited from Britain in September, was sentenced yesterday by a federal judge in Waco, ',
#   'sources': ['http://www.rte.ie/news/2016/0114/760237-patrick-sheridan-court/']},
#  'stéphane therrien': {'case_name': 'stéphane therrien',
#   'case_name_score': 100,
#   'case_name_context': 'Quebec. Between September 4, 2018, and January 3, 2019, Vincent Nadeau Morissette (Armagh, Quebec); Stéphane Therrien (Grondines, Quebec); and Serge Therrien (Grondines, Quebec) all pleaded guilty to a total of 17 cha',
#   'sources': ['https://www.canada.ca/en/environment-climate-change/services/environmental-enforcement/notifications/three-quebec-hunters-fined-breaking-federal-provincial-wildlife-laws.html']},
#  'brian miller': {'case_name': 'brian miller',
#   'case_name_score': 100,
#   'case_name_context': 'aid. Jay Reeder, Brandon Porter, Rick and Jesse Earl and Dustin Hollingsworth of Preston, Idaho and Brian Miller of Pennsylvania all reached plea agreements in a Franklin County court for the illegal killing and ',
#   'sources': ['https://www.cachevalleydaily.com/news/archive/2020/07/02/six-men-plead-guilty-to-poaching-29-big-game-animals-in-franklin-county/#.Xv9puShKg2w']},
#  'gregory logan': {'case_name': 'gregory logan',
#   'case_name_score': 100,
#   'case_name_context': 's v. Jeon Seon Han Vessel/APPS, Obstruction, Witness \nTampering \nDistrict of Maine United States v. Gregory Logan Narwhal Tusk Imports/\nConspiracy, Money Laundering \nEastern District of \nMichigan United States v. ',
#   'sources': ['https://www.justice.gov/enrd/page/file/912271/download',
#    'http://www.cbc.ca/news/canada/new-brunswick/narwhal-smuggle-rcmp-logan-u-s-1.3495603']},
#  'vanessa rondeau': {'case_name': 'vanessa rondeau',
#   'case_name_score': 100,
#   'case_name_context': ' Loaded Montreal Montreal woman arrested at U.S. border trying to transport sloth, crocodile skulls Vanessa Rondeau, the owner of The Old Cavern Boutique in Montreal, also was alleged to be in possession of two hors',
#   'sources': ['https://www.cbc.ca/news/canada/montreal/montreal-border-animal-parts-1.6045568']},
#  'phillip lang': {'case_name': 'phillip land',
#   'case_name_score': 92,
#   'case_name_context': 'tate and federal law enforcement agencies work together to combat the illegal wildlife trade," said Phillip Land, a Special Agent in Charge for the U.S. Fish and Wildlife Service. "We will vigorously investigate ',
#   'sources': ['https://www.justice.gov/usao-ndok/pr/new-jersey-man-sentenced-smuggling-over-1000-illegally-collected-box-turtles-oklahoma',
#    'https://www.justice.gov/usao-mdfl/pr/florida-man-sentenced-federal-prison-trafficking-endangered-species-and-illegally',
#    'https://www.justice.gov/usao-wdtx/pr/el-paso-man-pleads-guilty-role-scheme-sell-protected-cacti']},
#  'charles wood': {'case_name': 'charles good',
#   'case_name_score': 92,
#   'case_name_context': 'X LinkedIn Email For Immediate Release Office of Public Affairs William Sheldon, Timothy Lewis, and Charles Good appeared today in federal court in Portland, Maine, where each pleaded guilty to violating the Lace',
#   'sources': ['https://www.justice.gov/opa/pr/three-men-plead-guilty-illegally-trafficking-american-eels']},
#  'cai xiu mei': {'case_name': 'xiu mei cui',
#   'case_name_score': 91,
#   'case_name_context': 'animals into Canada. Environment and Climate Change Canada , which enforces conservation laws, says Xiu Mei Cui pleaded guilty Monday to two charges under the law regulating the trade of plants and animals. The ',
#   'sources': ['http://bc.ctvnews.ca/woman-fined-75k-for-importing-jewelry-made-from-endangered-species-1.3316564']},
#  'raymond sanders': {'case_name': 'raymond saunders',
#   'case_name_score': 97,
#   'case_name_context': 'ars of supervised release.\xa0 He was also ordered to pay $227 in restitution to the State of Florida. Raymond Saunders , 50, also of Riviera Beach, was convicted of one count of transporting sea turtle eggs for the pur',
#   'sources': ['https://www.justice.gov/usao-sdfl/pr/two-riviera-beach-men-sentenced-stealing-sea-turtle-eggs']},
#  'timothy lewis': {'case_name': 'timothy lewis',
#   'case_name_score': 100,
#   'case_name_context': '017 Share Facebook X LinkedIn Email For Immediate Release Office of Public Affairs William Sheldon, Timothy Lewis, and Charles Good appeared today in federal court in Portland, Maine, where each pleaded guilty to ',
#   'sources': ['https://www.justice.gov/opa/pr/three-men-plead-guilty-illegally-trafficking-american-eels']},
#  'jackie murphy': {'case_name': 'jack murphy',
#   'case_name_score': 92,
#   'case_name_context': ' to his home in Calgary, Krekhovetski reported the incident. Hambrook, Gilson and one other hunter, Jack Murphy, loaded the bear on a trailer and hid it in the woods a short distance away. When a Fish and Wildli',
#   'sources': ['https://lethbridgeherald.com/news/lethbridge-news/2020/03/19/sentencing-delayed-in-grizzly-bear-poaching-case/']},
#  'lisa peterson': {'case_name': 'lisa peterson',
#   'case_name_score': 100,
#   'case_name_context': 'and aquariums in providing world-class care for wildlife and responding in a moment’s notice,”\xa0said Lisa Peterson, executive director of the San Diego Zoo Safari Park.\xa0“In these difficult moments, we see it as our',
#   'sources': ['https://news.yahoo.com/3-spider-monkeys-confiscated-border-181328902.html?guccounter=1']},
#  'frank johnson': {'case_name': 'frank johnson',
#   'case_name_score': 100,
#   'case_name_context': 'ornia Department of Health. The nursing home is owned by Sunmar Healthcare in Brea. A call to owner Frank Johnson on Saturday was not immediately returned. The elderly patient was injured on Feb. 24 as a nursing a',
#   'sources': ['https://www.montereyherald.com/2007/12/02/state-briefs-2/']},
#  'frederick thompson': {'case_name': 'fredrick thomson',
#   'case_name_score': 94,
#   'case_name_context': 'ent and Climate Change Canada is taking action to protect wildlife and nature. On January 18, 2019, Fredrick Thomson (from Coaldale, Alberta) was sentenced in the Provincial Court of Alberta following his conviction ',
#   'sources': ['https://www.canada.ca/en/environment-climate-change/services/environmental-enforcement/notifications/alberta-based-taxidermist-sentenced-violations-federal-wildlife-law.html']},
#  'ryan hicks': {'case_name': 'ryan hicks',
#   'case_name_score': 100,
#   'case_name_context': 'determined that the day before, Ronald Hicks of St. Marys harvested a bear while party hunting with Ryan Hicks of Granton," reads a statement from the MNRF. "Ronald had previously used his bear tag during the s',
#   'sources': ['https://www.cbc.ca/news/canada/london/hunters-fined-suspended-kill-bears-1.5384763?__vfz=medium%3Dsharebar']},
#  'zhou hong xia': {'case_name': 'zhou hong xia',
#   'case_name_score': 100,
#   'case_name_context': ' $4.3 million has been seized in Markham, Ontario. On October 3, Nationalwide Star Canada Corp. and Zhou Hong Xia, both of Markham, were fined $175,000 and $75,000 respectively by the Ontario Court of Justice in T',
#   'sources': ['https://www.northshoredailypost.com/eel-meat-worth-more-than-4-3-million-seized-in-ontario/']},
#  'paul stewart': {'case_name': 'paul c. stewart',
#   'case_name_score': 92,
#   'case_name_context': 'term health issues, said Carli Segelson, spokeswoman for the commission. The owner of the property, Paul C. Stewart, was cited for possessing a class II animal without a permit and improper caging. He was also given',
#   'sources': ['https://bigcatrescue.org/illegally-kept-florida-siberian-lynx-seized-by-fwc/']},
#  'lauren le': {'case_name': 'lauren lowe',
#   'case_name_score': 90,
#   'case_name_context': 'airs News Press Releases U.S. Government Seizes 68 Protected Big Cats and a Jaguar From Jeffrey and Lauren Lowe MENU News All News Blogs Photo Galleries Podcasts Press Releases Speeches Videos Archived Press Rel',
#   'sources': ['https://www.justice.gov/opa/pr/us-government-seizes-68-protected-big-cats-and-jaguar-jeffrey-and-lauren-lowe']},
#  'dr.keith fleming': {'case_name': 'keith fleming',
#   'case_name_score': 90,
#   'case_name_context': 'uld devastate our livestock industries, sicken our citizens, and impact our nation’s economy,” said Keith Fleming, Acting Director of Field Operations for CBP’s Baltimore Field Office. “Customs and Border Protecti',
#   'sources': ['https://www.cbp.gov/newsroom/local-media-release/dulles-cbp-finds-100-prohibited-porcupine-quills',
#    'https://patch.com/virginia/herndon/crocodile-skin-bags-ivory-leeches-seized-dulles-airport',
#    'https://patch.com/virginia/herndon/crocodile-skin-bags-ivory-leeches-seized-dulles-airport',
#    'https://patch.com/virginia/herndon/crocodile-skin-bags-ivory-leeches-seized-dulles-airport']},
#  'michael bryant': {'case_name': 'michael bryant',
#   'case_name_score': 100,
#   'case_name_context': 'h of elvers in and around Millville, New Jersey, in 2013. His sentencing date has not yet been set. Michael Bryant, who was sentenced in May, Im and Choi are the only three men out of the 14 charged in federal cour',
#   'sources': ['https://bangordailynews.com/2017/12/15/news/portland/two-men-sentenced-in-baby-eel-trafficking-scheme/']},
#  'devin mullins': {'case_name': 'kevin mullins',
#   'case_name_score': 92,
#   'case_name_context': '. \xa0Ryan Justice, 28, of Randle, Washington, was sentenced in December 2015 to 15 months in prison.\xa0 Kevin Mullins, 56, of Packwood, Washington is scheduled for sentencing June 6, 2016. The case is being investigat',
#   'sources': ['https://www.justice.gov/usao-wdwa/pr/mill-owner-sentenced-prison-purchases-and-sales-stolen-figured-maple-national-forest']},
#  'anthony nguyen': {'case_name': 'anthony nguyen',
#   'case_name_score': 100,
#   'case_name_context': 'TTSBURGH (KDKA) -- A Pittsburgh man has pleaded guilty to trafficking endangered and invasive fish. Anthony Nguyen pleaded guilty in federal court on Tuesday. He owns Ichiban Tropical Fish, which sells rare and exo',
#   'sources': ['https://pittsburgh.cbslocal.com/2021/07/20/pittsburgh-man-guilty-trafficking-endangered-and-invasive-fish/']},
#  'william shelton': {'case_name': 'william sheldon',
#   'case_name_score': 93,
#   'case_name_context': 'day, October 5, 2017 Share Facebook X LinkedIn Email For Immediate Release Office of Public Affairs William Sheldon, Timothy Lewis, and Charles Good appeared today in federal court in Portland, Maine, where each ple',
#   'sources': ['https://www.justice.gov/opa/pr/three-men-plead-guilty-illegally-trafficking-american-eels']},
#  'james conley': {'case_name': 'james copley',
#   'case_name_score': 92,
#   'case_name_context': ' Brittney Marcum, 31, of Thurman, Randy Jones Jr., 64, of Thurman, Charlotte Jones, 63, of Thurman, James Copley, 58, of Thurman, Justin Wells, of Thurman, William Gilbert, 27, of Thurman and Justin Butterfield, ',
#   'sources': ['https://www.wsaz.com/2021/10/21/eight-indicted-stealing-deer-meat-illegally-poaching-white-tailed-deer/']},
#  'steven thomas': {'case_name': 'steve thomas',
#   'case_name_score': 96,
#   'case_name_context': " in Grady County on Christmas Eve. Since that county has no open season for killing bears, Corporal Steve Thomas investigated, learned the suspect's identity and found out where the bear was shot. Officers interv",
#   'sources': ['https://wgxa.tv/news/local/georgia-dnr-charges-florida-man-for-bear-poaching']},
#  'joshua harvey': {'case_name': 'joshua harvey',
#   'case_name_score': 100,
#   'case_name_context': 'n front of confiscated bear-bile products.                      (World Animal Protection/ Inspector Joshua Harvey) CHINATOWN, NY — Bear bile products thought by some to be a cure for the coronavirus were seized in',
#   'sources': ['https://patch.com/new-york/west-village/amp/29086771/thousands-of-dollars-of-bear-bile-products-seized-from-chinatown?utm_source=twitter&utm_medium=web&utm_campaign=share&__twitter_impression=true']},
#  'michael elliott': {'case_name': 'michael elliot',
#   'case_name_score': 97,
#   'case_name_context': 'A watchmaker from Kent has been given a two-year suspended sentence for illegally trading in ivory. Michael Elliot, 56, from Singlewell Road, in Gravesend, pleaded guilty to seven charges at Southwark Crown Court. ',
#   'sources': ['http://news.bbc.co.uk/1/hi/england/kent/7453092.stm']},
#  'carlos rodriguez': {'case_name': 'carlos rodriguez',
#   'case_name_score': 100,
#   'case_name_context': 'g this monkey is certainly unusual but not a first for our officers at Hidalgo,” said Port Director Carlos Rodriguez, Port of Hidalgo/Pharr/Anzalduas. “Our officers normally discover prohibited agriculture products, ',
#   'sources': ['https://www.cbp.gov/newsroom/local-media-release/cbp-field-operations-hidalgo-international-bridge-does-not-monkey',
#    'https://www.cbp.gov/newsroom/local-media-release/cbp-agriculture-specialists-seize-illegally-harvested-seafood-imported',
#    'https://www.cbp.gov/newsroom/local-media-release/cbp-officers-discover-undeclared-reptiles-hidalgo-international-bridge']},
#  'xiong chang': {'case_name': 'chang xiong',
#   'case_name_score': 100,
#   'case_name_context': ' in 2016, and it led to a search on Dec. 12 of a home in the 4700 block of Helmo Avenue occupied by Chang Xiong and his wife, Ma Chang. Search warrant documents unsealed Wednesday in federal court in St. Paul sh',
#   'sources': ['https://www.startribune.com/feds-seize-rhinoceros-elephant-parts-from-oakdale-home/503867462/']},
#  'liu feng': {'case_name': 'fen liu',
#   'case_name_score': 93,
#   'case_name_context': 'l Depot Corporation of Totowa, New Jersey Yi Rui Huang, aka Ricky, 47, of Oakland Gardens, New York Fen Liu, aka Emily, 45, of Oakland Gardens, New York Chao Jin Shi, aka Kevin, 49, of Flushing, New York Guo',
#   'sources': ['https://www.justice.gov/opa/pr/major-seafood-dealer-and-eight-individuals-indicted-international-wildlife-trafficking']},
#  'robert brewer': {'case_name': 'robert brewer',
#   'case_name_score': 100,
#   'case_name_context': 'nt’s ability to pay. “Illegal trafficking in fish and wildlife is big business,” said U.S. Attorney Robert Brewer.\xa0 “We are committed to working with our law enforcement partners to protect endangered wildlife.” B',
#   'sources': ['https://www.justice.gov/usao-sdca/pr/sea-cucumber-smuggler-sentenced-eight-months-jail']},
#  'greg anderson': {'case_name': 'greg anderson',
#   'case_name_score': 100,
#   'case_name_context': 'CBC News Loaded British Columbia B.C. man who tried to smuggle baby lizards across border fined $6K Greg Anderson was fined after failing to declare six endangered lizards he had with him when he tried to cross th',
#   'sources': ['http://www.cbc.ca/news/canada/british-columbia/lizards-smuggled-canada-border-1.3896499']},
#  'heather navarro': {'case_name': 'heather navarro',
#   'case_name_score': 100,
#   'case_name_context': "life at the Alpine facility. Copyright CNS - City News Service This article tagged under: Louisiana Heather Navarro Alpine Trending Stories Mexico San Diego couple reaches settlement after toddler's 9-story fall at ",
#   'sources': ['https://www.nbcsandiego.com/news/local/neglected-white-tiger-san-diego-exotic-pet-trade/148205/']},
#  'christy miller': {'case_name': 'chris miller',
#   'case_name_score': 92,
#   'case_name_context': " February 5, 2024 - 10:29 am View All Hoppy's Commentary February 12, 2024 I'm off February 8, 2024 Chris Miller is making noise in the governor's race February 6, 2024 The political mine field of border policy F",
#   'sources': ['https://wvmetronews.com/2020/10/17/virginia-man-admits-to-poaching-buck-in-pendleton-county/']},
#  'he jun': {'case_name': 'jung he',
#   'case_name_score': 92,
#   'case_name_context': 'ovember 5,\xa0in the Ontario Court of Justice in Parry Sound, Justice of the Peace Cornelia Mews fined Jung He (Audley) Park of McKellar $6,000 for unlawfully buying and possessing black bear gall bladders. Bon',
#   'sources': ['https://www.sootoday.com/around-ontario/ontario-heavy-fine-for-couple-buying-black-bear-gall-bladders-1880279']},
#  'jacob lane': {'case_name': 'jacob lane',
#   'case_name_score': 100,
#   'case_name_context': 'ish and Wildlife Service. Adam T. Sage, 24, Michael R. Tuzroyluk Jr., 21, Guy S. Tuzroyluk, 27, and Jacob Lane, 24, residents of Point Hope, Alaska, pleaded guilty in federal court in Fairbanks for violations o',
#   'sources': ['https://www.justice.gov/usao-ak/pr/point-hope-walrus-hunters-sentenced-federal-violations']},
#  'richard parker': {'case_name': 'richard parker',
#   'case_name_score': 100,
#   'case_name_context': 'nesday after making the gruesome discovery in Standish, a community in Lassen County. They arrested Richard Parker, 67, on multiple charges including taking birds of prey, taking migratory non-game birds as designa',
#   'sources': ['http://www.rgj.com/story/life/outdoors/2018/03/14/authorities-arrest-man-mass-killing-raptors-near-honey-lake/426809002/']},
#  'paula simon': {'case_name': 'simon paul',
#   'case_name_score': 95,
#   'case_name_context': "rogrammes Weather Two charged over 'killing spree' of 3,600 birds, including bald eagles in Montana Simon Paul and Travis John Branson face up to five years in prison and a $250,000 (£200,000) fine if they are ",
#   'sources': ['https://news.sky.com/story/two-charged-over-killing-spree-of-3-600-birds-including-bald-eagles-in-montana-13029806']},
#  'victoria cuevas': {'case_name': 'victor cuevas',
#   'case_name_score': 93,
#   'case_name_context': 'ame with this $96 car infotainment system Local News Jury decides sentence for murder conviction of Victor Cuevas, man who fled west Houston neighborhood with tiger in 2021 Brittany Taylor , Digital Content Produc',
#   'sources': ['https://www.click2houston.com/news/local/2022/05/10/victor-cuevas-man-who-fled-west-houston-neighborhood-with-tiger-in-2021-sentenced-in-murder-conviction/']},
#  'michael clements': {'case_name': 'michael clemons',
#   'case_name_score': 90,
#   'case_name_context': '2) –Possess with intent to sell/deliver F.S.S. 893.13(6)(a) –Possess controlled substance (THC oil) Michael Clemons (DOB 09/05/1996 Fort Myers, FL): F.S.S. 812.019(1) –Dealing in stolen property F.A.C. 68A-25.002 (6',
#   'sources': ['https://www.winknews.com/2019/10/18/fwc-busts-wildlife-trafficking-ring-smuggling-thousands-of-turtle/?__cf_chl_captcha_tk__=2cae411a66c3ed1b132ce9390840aa09a946c74a-1617802383-0-AemoG1dMHR15risH805OqkOeo0EQ_n3-HVv553z8We35UW9GVzElKe7E3EI6cAn6foOltEuif_Ha']},
#  'christopher hale': {'case_name': 'christopher l. hale.',
#   'case_name_score': 94,
#   'case_name_context': "Skip to main content An official website of the United States government Here's how you know Here's how you know Offici",
#   'sources': ['https://www.justice.gov/opa/pr/owner-arecibo-aquarium-business-pleads-guilty-two-federal-lacey-act-felonies-illicit',
#    'https://www.justice.gov/opa/pr/lumber-liquidators-inc-sentenced-illegal-importation-hardwood-and-related-environmental']},
#  'bryan berg': {'case_name': 'bryan berg',
#   'case_name_score': 100,
#   'case_name_context': ' in self-defense because he was mad that the bear was going to eat him, according to court records. Bryan Berg, 35, appeared in court on Thursday in U.S. District Court in Missoula after pleading guilty to ille',
#   'sources': ['https://eu.greatfallstribune.com/story/news/2020/01/18/man-kills-grizzly-self-defense-keeps-claws-memento/4512910002/']},
#  'ind.michael brooks': {'case_name': 'michael d. brooks',
#   'case_name_score': 94,
#   'case_name_context': 'Van Durme, of the environmental crimes investigation unit. Two Long Island men, Adam C. Borisuk and Michael D. Brooks, sent tens of thousands of young snapping turtle hatchlings, collected from freshly laid nests of e',
#   'sources': ['https://cityroom.blogs.nytimes.com/2009/03/19/reptile-smuggling-ring-is-broken-authorities-say/?_r=1']},
#  'joseph torres': {'case_name': 'jose torres',
#   'case_name_score': 92,
#   'case_name_context': 'also charges Renaissance and Bryant with conspiracy and attempting to unlawfully export live coral. Jose Torres, 42, of Gardena, was charged with unlawfully attempting to export to Mexico 20 varieties of live, C',
#   'sources': ['https://www.justice.gov/usao-cdca/pr/grand-jury-issues-indictments-alleging-three-schemes-smuggle-protected-coral-species',
#    'https://robindesbois.org/wp-content/uploads/ON_THE_TRAIL_18.pdf']},
#  'michael kelly': {'case_name': 'michael kelly',
#   'case_name_score': 100,
#   'case_name_context': 's nearly 120 animals were seized, including parrots, six camels, 36 goats and two Capuchin monkeys. Michael Kelly, spokesman for Attorney General Mark Herring, said animal-control and animal-rescue organizations a',
#   'sources': ['https://apnews.com/article/d341ba0db0134f398cfd88a5b2801b00']},
#  'david paré': {'case_name': 'david pharo',
#   'case_name_score': 90,
#   'case_name_context': 'igative efforts related to the entire span of the marine life trade,” said Resident Agent in Charge David Pharo of the U.S. Fish and Wildlife Service. “Whether responsibility lies as the initial harvester, whole',
#   'sources': ['https://www.justice.gov/opa/pr/owner-arecibo-aquarium-business-pleads-guilty-two-federal-lacey-act-felonies-illicit',
#    'https://www.justice.gov/usao-sdfl/pr/nevada-resident-pled-guilty-and-was-sentenced-miami-trafficking-endangered-galapagos',
#    'https://www.justice.gov/usao-sdfl/pr/defendants-sentenced-capturing-and-restraining-endangered-key-deer']},
#  'joseph kelley': {'case_name': 'joseph kelley',
#   'case_name_score': 100,
#   'case_name_context': 'ay, January 18, 2018 Share Facebook X LinkedIn Email For Immediate Release Office of Public Affairs Joseph Kelley and James Lewis were each indicted in Newark, New Jersey, with crimes related to illegally traffick',
#   'sources': ['https://www.justice.gov/opa/pr/two-men-indicted-illegally-trafficking-american-eels']},
#  'janet rodriguez': {'case_name': 'jafet rodriguez',
#   'case_name_score': 93,
#   'case_name_context': '    District of Vermont The Office of the United States Attorney for the District of Vermont stated Jafet Rodriguez, 39, of Hazleton Pennsylvania, has been charged with unlawfully smuggling tropical birds into Vermo',
#   'sources': ['https://www.justice.gov/usao-vt/pr/pennsylvania-man-charged-smuggling-endangered-tropical-birds-vermont']},
#  'rose jackson': {'case_name': 'jackson roe',
#   'case_name_score': 96,
#   'case_name_context': 's LITTLE ROCK—A Conway man has pleaded guilty to importing and possessing illegally taken wildlife. Jackson Roe, 27, entered his guilty plea Wednesday afternoon before Chief United States District Judge D. Price',
#   'sources': ['https://www.justice.gov/usao-edar/pr/conway-man-pleads-guilty-importation-and-possession-illegally-taken-wildlife',
#    'https://www.arkansasonline.com/news/2019/dec/08/grand-jury-indicts-conway-man-tied-to-s/',
#    'https://www.arkansasonline.com/news/2019/dec/08/grand-jury-indicts-conway-man-tied-to-s/',
#    'https://www.justice.gov/usao-edar/pr/conway-man-pleads-guilty-importation-and-possession-illegally-taken-wildlife',
#    'https://www.justice.gov/usao-edar/pr/conway-man-pleads-guilty-importation-and-possession-illegally-taken-wildlife',
#    'https://www.justice.gov/usao-edar/pr/conway-man-pleads-guilty-importation-and-possession-illegally-taken-wildlife']},
#  'tonya jones': {'case_name': 'toney jones',
#   'case_name_score': 91,
#   'case_name_context': 'ay announced the unsealing of an indictment charging Dr. John Waldrop, 74, of Cataula, Georgia, and Toney Jones, 53, of Eufala, Alabama, on conspiracy, smuggling, Endangered Species... October 11, 2023 Office of',
#   'sources': ['https://www.justice.gov/opa/pr/alleged-head-wildlife-smuggling-ring-extradited-australia',
#    'https://www.justice.gov/opa/pr/owner-arecibo-aquarium-business-pleads-guilty-two-federal-lacey-act-felonies-illicit',
#    'https://www.justice.gov/opa/pr/two-men-indicted-illegally-trafficking-american-eels',
#    'https://www.justice.gov/opa/pr/pennsylvania-man-indicted-trafficking-turtles',
#    'http://www.justice.gov/opa/pr/2012/February/12-enrd-246.html',
#    'https://www.justice.gov/usao-edny/pr/florida-couple-pleads-guilty-brooklyn-federal-court-smuggling-protected-lovebirds',
#    'http://www.justice.gov/opa/pr/two-california-men-indicted-selling-endangered-black-rhinoceros-horns',
#    'https://www.justice.gov/opa/pr/indiana-man-pleads-guilty-lacey-act-violations',
#    'https://www.justice.gov/opa/pr/canadian-antique-dealer-charged-trafficking-wildlife']},
#  'brandon porter': {'case_name': 'brandon porter',
#   'case_name_score': 100,
#   'case_name_context': 'tah Division of Wildlife Resource. The incident occurred in 2018, a press release said. Jay Reeder, Brandon Porter, Rick and Jesse Earl and Dustin Hollingsworth of Preston, Idaho and Brian Miller of Pennsylvania al',
#   'sources': ['https://www.cachevalleydaily.com/news/archive/2020/07/02/six-men-plead-guilty-to-poaching-29-big-game-animals-in-franklin-county/#.Xv9puShKg2w']},
#  'ryan gibbs': {'case_name': 'ryan j. gibbs',
#   'case_name_score': 91,
#   'case_name_context': ' violating the Endangered Species Act, according to the U.S. Attorney’s Office. Court documents say Ryan J. Gibbs, 44, contacted a man in the United Kingdom in Aug. 2018 about buying a tiger skin rug. The man told',
#   'sources': ['https://www.fox19.com/2020/08/12/cincinnati-man-pleads-guilty-after-buying-tiger-skin-k/']},
#  'james miller': {'case_name': 'james miller',
#   'case_name_score': 100,
#   'case_name_context': 'the maple trees in the Gifford Pinchot National Forest in November and December 2011 and May 2012.\xa0 James Miller, 36, of Morton, Washington was sentenced in February 2016 to six months in prison and three years o',
#   'sources': ['https://www.justice.gov/usao-wdwa/pr/mill-owner-sentenced-prison-purchases-and-sales-stolen-figured-maple-national-forest']},
#  'pedro ramirez': {'case_name': 'pedro ramírez',
#   'case_name_score': 96,
#   'case_name_context': 'rts have been successful in the eyes of a member\xa0of the Escobilla sea turtle sanctuary cooperative. Pedro Ramírez told Dolores Barrientos Alemán, Mexico representative of the United Nations Environment Program, th',
#   'sources': ['https://mexiconewsdaily.com/news/30000-turtle-eggs-seized/']},
#  'ryan millar': {'case_name': 'ryan millar',
#   'case_name_score': 100,
#   'case_name_context': ' Tofino, the Conservation Officer Service (COS) says in what it’s calling a precedent-setting case. Ryan Millar was sentenced in Tofino Court Monday after killing a black bear and her cub during closed season in',
#   'sources': ['https://vancouver.citynews.ca/2023/11/07/bc-bear-cub-killed-jail/']},
#  'jon castillo': {'case_name': 'jonen castillo',
#   'case_name_score': 92,
#   'case_name_context': ', Florida – United States Attorney Roger B. Handberg announces the return of an indictment charging Jonen Castillo (23, Orlando) with smuggling firearms from the United States to Canada. If... February 15, 2024 Pre',
#   'sources': ['https://www.justice.gov/usao-mdfl/pr/florida-man-sentenced-federal-prison-trafficking-endangered-species-and-illegally']},
#  'gérard thériault': {'case_name': 'gérald thériault',
#   'case_name_score': 93,
#   'case_name_context': 'ession of Crown wood | CBC News Loaded New Brunswick $12K fine for illegal possession of Crown wood Gérald Thériault of Sainte-Anne de Madawaska has been fined $12,000 for the illegal possession of timber from Crown ',
#   'sources': ['https://www.cbc.ca/news/canada/new-brunswick/crown-wood-illegal-possession-1.4779492']},
#  'kim tran': {'case_name': 'kiem tran',
#   'case_name_score': 94,
#   'case_name_context': 'g for the illegal sale of Asian arowanas in this district in the last two weeks. In a related case, Kiem Tran, the owner of the Fish Warehouse in Westminster, California, was sentenced on May 16, 2014, to a te',
#   'sources': ['https://www.justice.gov/usao-sdca/pr/online-merchant-convicted-trafficking-endangered-fish']},
#  'chen liang': {'case_name': 'liang chen',
#   'case_name_score': 100,
#   'case_name_context': ' Jin Shi, aka Kevin, 49, of Flushing, New York Guo Tuan Zhou, aka Jason, 45, of Woodhaven, New York Liang Chen, aka Jackie, 33, of Fujian, China Yundong Wei, 42, of Fuzhou, China Xiajuan Huang Zhouyi, 46, of Ch',
#   'sources': ['https://www.justice.gov/opa/pr/major-seafood-dealer-and-eight-individuals-indicted-international-wildlife-trafficking']},
#  'brandon stephenson': {'case_name': 'brad stephenson',
#   'case_name_score': 91,
#   'case_name_context': 'ge of hunting wildlife in a closed season. “This is a clear-cut case of poaching,” Crown prosecutor Brad Stephenson said. Court was told a man called the Alberta Fish and Wildlife Report a Poacher line Oct. 30 to re',
#   'sources': ['https://www.fortmacleodgazette.com/2014/youth-fined-for-role-in-death-of-grizzly-bear/']},
#  'brian hart': {'case_name': 'brian hart',
#   'case_name_score': 100,
#   'case_name_context': 'ailable. Archived This page has been archived on the Web. Sarnia, Ontario -- August 24, 2011 -- Mr. Brian Hart of Bowmanville, Ontario pleaded guilty on August 12, 2011 in the Ontario Court of Justice in Sarnia',
#   'sources': ['https://www.canada.ca/en/environment-climate-change/services/environmental-enforcement/notifications/illegal-import-kulans.html']}}

# %%
with open('names_metadata.json', 'w') as file:
    json.dump(results, file, indent=4)

# %%
# the context key in results provides a peek at 100 chars before and 100 chars after when the name was mentioned
# we went through these to make sure that the names were not of attorney generals, officers, etc
# though we tried to do this when sanitizing the LLM output, some names still slipped through

# DON'T RUN THIS CELL IF YOU DON'T WANT TO REMOVE THESE NAMES!

names_to_remove = [
    'dr.jeffrey wood',
    'edward walker',
    'gabrielle harper',
    'james hayes',
    'christy ford',
    'jeffery richards',
    'kara rodriguez',
    'jerome nicholson',
    'phillip lang',
    'frank johnson',
    'dr.keith fleming',
    'steven thomas',
    'joshua harvey',
    'carlos rodriguez',
    'robert brewer',
    'heather navarro',
    'christy miller',
    'christopher hale',
    'david paré',
    'pedro ramirez',
    'brandon stephenson'

    ]

results_copy = results.copy()
for name in names_to_remove:
    del results_copy[name]

with open('names_metadata.json', 'w') as file:
    json.dump(results_copy, file, indent=4)
