# %%
from fuzzywuzzy import process
from fuzzywuzzy import fuzz
from tqdm import tqdm
import pandas as pd
import pickle
import copy
import json
import glob
import time
import io

# %% [markdown]
# # Matching

# %%
names = []
with open('./westlaw/westlaw_names.txt', 'r', encoding='utf-8') as f:
    for line in f:
        names.append(line.strip().capitalize())

with open('./traffic/incident_names.txt', 'r', encoding='utf-8') as f:
    for line in f:
        names.append(line.strip().capitalize())

kyc = pd.read_parquet('../data/processed/nodes.parquet')

# %%
# Function to find best match
def find_best_matches(name, ref_db, scorer):
    best = process.extractOne(name, ref_db, scorer=scorer)[1]
    return process.extractBests(name, ref_db, scorer=scorer, score_cutoff=best, limit=10)

# %%
# Normalize data (to lowercase in this example)
internet_names = [name.lower() for name in names]
kyc_names = [name.lower() for name in kyc.name]

# Finding matches
matches = {
    match[0]: {query, match[1]} 
    for query in tqdm(internet_names)
    for match in find_best_matches(query, kyc_names, fuzz.ratio)}

matches_sort_ratio = {
    match[0]: {query, match[1]} 
    for query in tqdm(internet_names)
    for match in find_best_matches(query, kyc_names, fuzz.token_sort_ratio)}
# Out:
#   2%|██▎                                                                                                        | 27/1252 [00:58<44:37,  2.19s/it]WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████| 1252/1252 [44:52<00:00,  2.15s/it]
#   2%|██▎                                                                                                      | 27/1252 [01:49<1:22:10,  4.03s/it]WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████| 1252/1252 [1:22:22<00:00,  3.95s/it]

# %%
def set_to_dict(s: set):
    d = {}
    for item in s:
        if isinstance(item, int):
            d['score'] = item
        else:
            d['query'] = item
    return d

# %%
m = copy.deepcopy(matches)
m = {n: set_to_dict(s) for n,s in m.items()}

msort = copy.deepcopy(matches_sort_ratio)
msort = {n: set_to_dict(s) for n,s in msort.items()}

# %%
with open('m_temp.json', 'w') as f:
    json.dump(m,f)
    
with open('msort_temp.json', 'w') as f:
    json.dump(msort, f)

# %% [markdown]
# # Cleaning

# %%
names_to_remove = [
    'jeffrey wood',
    'edward walker',
    'gabrielle harper',
    'james hayes',
    'christy ford',
    'jeffery richards',
    'kara rodriguez',
    'joseph nicholson',
    'phillip lang',
    'frank johnson',
    'dr.keith fleming',
    'steven thomas',
    'joshua harvey',
    'carlos rodriguez',
    'robert brewer',
    'heather navarro',
    'christy miller',
    'christopher hall',
    'david paré',
    'pedro ramirez',
    'brandon stephenson',
    "kevin oneal",
    "lisa peterson",
    "victoria cuevos",
    "rose jackson",    
    ]

# %%
m = {n: v for n,v in m.items() if v['score'] > 90}
msort = {n: v for n,v in msort.items() if v['score'] > 90}
merged = m | msort 
merged = {n:v for n,v in merged.items() if v['query'] not in names_to_remove }
merged = dict(sorted(merged.items(), key=lambda item: item[1]['query']))

# I only want to keep queries with multiple matches
queries = [v['query'] for v in merged.values()]
duplicates = [item for item in queries if queries.count(item) > 1]
duplicates

# Filter and export the json
merged = {k:v for k,v in merged.items() if v['query'] in duplicates}
with open('multimatch.json', 'w') as f: 
    json.dump(merged, f)

# %%
m = {n: set_to_dict(s) for n,s in m.items()}
m = []
# Out:
# {'andrea francisca rangel verduzco': {'query': 'andrew stanley paul randy larry chickite curtis michael blaney ralph edward wilson',
#   'score': 44},
#  'john hooper': {'score': 75, 'query': 'john a. hofer'},
#  'john hoover': {'score': 75, 'query': 'john a. hofer'},
#  'paul francis': {'score': 73, 'query': 'paul francis smallboy'},
#  'dr.vincent castillo': {'query': 'irvine scalplock', 'score': 63},
#  'barbara payne phd': {'score': 59, 'query': 'bear paw pawn ltd.'},
#  'armaan lad': {'score': 59, 'query': 'bear paw pawn ltd.'},
#  'louis chartrand': {'query': 'gloria chartrand', 'score': 84},
#  'shawn lawrence md': {'score': 80, 'query': 'shawn lawrence lamouche'},
#  'jason gallagher': {'query': 'jan alsager', 'score': 77},
#  'edwin johnson': {'score': 65, 'query': 'edwin j. naytowhow'},
#  'anthony snow': {'query': 'anthony naytowhow', 'score': 76},
#  'anthony nash': {'query': 'anthony naytowhow', 'score': 76},
#  'dr.alexander camacho': {'query': 'lloyd alexander mcmahon', 'score': 79},
#  'william blanchette': {'score': 73, 'query': 'william james tschetter'},
#  'sarah kim': {'score': 67, 'query': 'yunhee (sarah) kim'},
#  'carlos potts': {'score': 64, 'query': 'malcolm j. potts'},
#  'béatrice moreau': {'score': 75, 'query': 'beatrice moosemay'},
#  'paul george': {'score': 83, 'query': 'samuel george'},
#  'ernest garcia': {'query': 'ernest cardinal', 'score': 79},
#  'ernest martin': {'query': 'ernest cardinal', 'score': 79},
#  'katherine charles': {'query': 'mathew alfred charles', 'score': 74},
#  'peter charles': {'score': 81, 'query': 'david peter charles'},
#  'dr.maurice boutin-roy': {'query': 'errol maurice bear aka errol maurice moosemay',
#   'score': 52},
#  'bernardo mauricio tamayo herrera': {'score': 49,
#   'query': 'eduardo mauricio, dueño del santuario black jaguar-white tiger.'},
#  'kenneth wilson': {'query': 'kenneth wilson lamouche', 'score': 76},
#  'mtro. teodoro salazar': {'query': 'elmer san pedro baldonaza', 'score': 61},
#  'jonathan blanchette': {'score': 73, 'query': 'nathan benjamin tschetter'},
#  'antoine maltais': {'query': 'valentin alatiit', 'score': 65},
#  'william medina': {'query': 'william james cardinal', 'score': 78},
#  'brian greer': {'query': 'brian general', 'score': 83},
#  'lawrence franklin': {'score': 75, 'query': 'lawrence francis prince'},
#  'dr.louis-guy lepage': {'score': 0, 'query': '颜某'},
#  'dr.tsvetkova anzhelika artemovna': {'score': 0, 'query': '颜某'},
#  'laurie lemay': {'score': 0, 'query': '颜某'},
#  'marcel bérubé': {'score': 0, 'query': '颜某'},
#  'erica gonzalez': {'score': 0, 'query': '颜某'},
#  'jérôme rousseau': {'score': 0, 'query': '颜某'},
#  "svetlana jur'evna beljaeva": {'score': 0, 'query': '颜某'},
#  'xu qin': {'score': 0, 'query': '颜某'},
#  'karen smith': {'score': 0, 'query': '颜某'},
#  'ronald baxter': {'score': 0, 'query': '颜某'},
#  'terry daniel': {'score': 96, 'query': 'terry daniels'},
#  "grigor'eva regina konstantinovna": {'query': 'without proper documentation or legal ownership. the person is not named',
#   'score': 42},
#  'doronina lora konstantinovna': {'query': 'without proper documentation or legal ownership. the person is not named',
#   'score': 42},
#  "terent'eva ekaterina ivanovna": {'query': 'without proper documentation or legal ownership. the person is not named',
#   'score': 42},
#  'tomás anguiano medrano': {'score': 68, 'query': 'octavio anguiano munoz'},
#  'alfredo homero arteaga castellanos': {'query': "to save a cooper's hawk that was injured and unable to fly. the article does not mention any individuals who were arrested or charged with a crime related to wildlife trafficking. therefore",
#   'score': 27},
#  'bryan norton': {'query': 'brayden norton', 'score': 85},
#  'brian norton': {'query': 'brayden norton', 'score': 85},
#  'madison black': {'query': 'dickson lau', 'score': 67},
#  'madison clark': {'query': 'dickson lau', 'score': 67},
#  'song lu': {'query': 'dickson lau', 'score': 67},
#  'jackson avila': {'query': 'dickson lau', 'score': 67},
#  'madison avila': {'query': 'dickson lau', 'score': 67},
#  'james lewis': {'score': 100, 'query': 'james lewis'},
#  'dr.luis cardenas': {'score': 83, 'query': 'luis cárdenas'},
#  'scapescare': {'query': 'campeche', 'score': 67},
#  'shlok sami': {'query': 'hiroyuki kasagami', 'score': 59},
#  'richard austin': {'query': 'richard d. austin', 'score': 90},
#  'nathan houston': {'score': 77, 'query': 'nyjah huston'},
#  'qian qiang': {'query': 'qian wen qing', 'score': 78},
#  'henriette bouchard-cloutier': {'score': 48,
#   'query': 'henry juszkiewicz, ceo of gibson guitar corp.'},
#  'felicia frederick': {'query': 'policía federal', 'score': 62},
#  'dr. ofelia madera': {'query': 'pf: policía federal', 'score': 61},
#  'victor dion': {'query': 'víctor ‘n’', 'score': 70},
#  'victor king': {'query': 'víctor ‘n’', 'score': 70},
#  'victor hunt': {'query': 'víctor ‘n’', 'score': 70},
#  'victor st-jean': {'query': 'víctor ‘n’', 'score': 70},
#  'victor wang': {'query': 'víctor ‘n’', 'score': 70},
#  'victor jean': {'query': 'víctor ‘n’', 'score': 70},
#  'victor chan': {'query': 'víctor ‘n’', 'score': 70},
#  'efimova marina semenovna': {'query': 'fiona skye mckenna', 'score': 62},
#  'dr dale connor': {'score': 85, 'query': 'dale connour'},
#  'wanda lara': {'score': 67, 'query': 'guadalajara'},
#  'badal kara': {'score': 67, 'query': 'guadalajara'},
#  'ethan nguyen': {'query': 'thi kim loan nguyen', 'score': 71},
#  'richard atkinson': {'score': 81, 'query': 'richard mckinnon'},
#  'esmeralda juan carlos archuleta hernandes': {'score': 34,
#   'query': 'the smugglers, who were being sought by customs and the dea, as well as the department of fish and wildlife.'},
#  'glafira aleksandrovna haritonova': {'score': 41,
#   'query': 'as well as five scuba tanks and scuba diving gear in the trunk of wang’s car'},
#  'christiane-gabrielle villeneuve': {'query': 'his toyota sedan and dive gear were seized as evidence',
#   'score': 45},
#  "aleksandrov eremej vasil'evich": {'query': 'his toyota sedan and dive gear were seized as evidence',
#   'score': 45},
#  'esteban elvia de la rosa serna': {'query': 'se menciona que la profepa impuso medidas de seguridad',
#   'score': 50},
#  'ind.étienne-gérard lavigne': {'query': 'his toyota sedan and dive gear were seized as evidence',
#   'score': 45},
#  'ind.daniel bernard-lavigne': {'query': 'his toyota sedan and dive gear were seized as evidence',
#   'score': 45},
#  "stepanov tverdislav arsen'evich": {'query': 'his toyota sedan and dive gear were seized as evidence',
#   'score': 45},
#  'sara goel': {'score': 67, 'query': 'israel'},
#  'lisa bell': {'score': 67, 'query': 'israel'},
#  'lisa neal': {'score': 67, 'query': 'israel'},
#  'sara neal': {'score': 67, 'query': 'israel'},
#  'louis gravel': {'score': 67, 'query': 'israel'},
#  'sara bell': {'score': 67, 'query': 'israel'},
#  'dr.dorothée trottier-boudreau': {'score': 50,
#   'query': 'brief overview of the wildlife crime control bureau'},
#  'jeffrey wood': {'score': 89, 'query': 'jeffrey h. wood'},
#  'edward walker': {'query': 'edward o. walker', 'score': 90},
#  'randy jones': {'query': 'randy jones jr.', 'score': 88},
#  'joy randall': {'query': 'floyd kendall', 'score': 67},
#  'theresa scott': {'score': 60, 'query': 'the transportista'},
#  'teresa norris': {'score': 60, 'query': 'the transportista'},
#  'hilda beatriz mayorga solano': {'query': 'noel bowater, lord mayor of london',
#   'score': 55},
#  'gilles allain': {'query': 'gilles allain', 'score': 100},
#  'hao jian hua': {'query': 'chao jin shi', 'score': 75},
#  'alvaro jáquez': {'score': 73, 'query': 'alvaro "j"'},
#  'santiago espartaco montañez huerta': {'score': 29,
#   'query': 'no specific individuals are mentioned as being responsible for the death of the black bear. the article mentions that the procuraduría federal de protección al ambiente'},
#  'clara maría del carmen chavarría salgado': {'query': 'los inspectores de la profepa que determinaron que la madera pertenecía a la especie dalbergia granadillo',
#   'score': 40},
#  'patricia ho': {'query': 'patricia', 'score': 84},
#  "dr.terent'ev mart'jan evstigneevich": {'query': "east valley teen assaults: photos: gilbert police asking for help identifying victims, suspects in teen violence cases. chief michael soelberg shared photos and videos of four cases gilbert police are investigating involving teen violence and the 'gilbert goons' gang.",
#   'score': 21},
#  'vihaan ram': {'query': 'harm', 'score': 57},
#  'kim harmon': {'query': 'harm', 'score': 57},
#  'sharon kim': {'query': 'harm', 'score': 57},
#  'adah sarma': {'query': 'harm', 'score': 57},
#  'mahika ram': {'query': 'harm', 'score': 57},
#  'charvi ram': {'query': 'harm', 'score': 57},
#  'arhaan ram': {'query': 'harm', 'score': 57},
#  'chad ramos': {'query': 'harm', 'score': 57},
#  'harry mayo': {'query': 'harm', 'score': 57},
#  'alejandro martin': {'query': 'azulejo mariposa', 'score': 62},
#  'ekaterina rubenovna prohorova': {'query': 'no puedo extraer ningún nombre de la información proporcionada.',
#   'score': 44},
#  'heather charles': {'query': 'other charges', 'score': 79},
#  'theresa charles': {'query': 'other charges', 'score': 79},
#  'loginov rodion fadeevich': {'score': 40,
#   'query': 'hk customs plans to tighten control on production of optical discs'},
#  'dr.polina olegovna rodionova': {'score': 40,
#   'query': 'hk customs plans to tighten control on production of optical discs'},
#  'colette-caroline michaud': {'score': 40,
#   'query': 'hk customs plans to tighten control on production of optical discs'},
#  'miss kristen norton phd': {'score': 40,
#   'query': 'hk customs plans to tighten control on production of optical discs'},
#  'kira svjatoslavovna konstantinova': {'score': 40,
#   'query': 'hk customs plans to tighten control on production of optical discs'},
#  'cristian marco antonio olivas': {'score': 40,
#   'query': 'hk customs plans to tighten control on production of optical discs'},
#  'maría cristina georgina castellanos abrego': {'score': 32,
#   'query': 'the 36-year-old man who was traveling from georgetown, guyana and was found to have 40 finches concealed in hair rollers in his baggage.'},
#  'michele flores': {'score': 65, 'query': 'mexico. therefore'},
#  'cristobal dulce maría leal ledesma': {'query': 'sino una noticia sobre la aseguramiento de madera ilegal en michoacán',
#   'score': 45},
#  'josé carlos espartaco zaragoza alba': {'query': 'por carecer los responsables de la documentación que acreditara la legalidad del funcionamiento de ambos. además',
#   'score': 37},
#  'rodolfo araceli arias morales': {'score': 50,
#   'query': 'centros de almacenamiento y transformación de materias primas forestales'},
#  'heather rocha': {'query': 'panthera onca', 'score': 69},
#  'carolina cornelio ballesteros mireles': {'score': 25,
#   'query': 'la información proporcionada no contiene nombres de personas o entidades que hayan sido acusadas de delitos ambientales. la noticia se enfoca en la aseguramiento de madera ilegal y la detección de irregularidades en transportistas'},
#  'maría del carmen miguel ángel tovar ponce': {'query': 'use a news aggregator website or app that collects articles from multiple sources, including the daily mail. some popular options include google news, apple news, and flipboard.',
#   'score': 28},
#  'rodrigo jorge luis villegas de anda': {'query': 'the wildlife trust of india for its help in researching wildlife trafficking cases in india.',
#   'score': 38},
#  'maría del carmen armando ballesteros guerra': {'query': 'the 20-year-old female u.s. citizen driver who attempted to smuggle the spider monkeys across the border.',
#   'score': 37},
#  'dipl.-ing. heinz-dieter gorlitz b.a.': {'query': 'it mentions that the inspectors detected the storage of wood without proper documentation',
#   'score': 37},
#  'dipl.-ing. ann-kathrin geisler': {'query': 'the couple who was trying to sell the elephant feet stools, as they were in possession of illegal wildlife products and were attempting to sell them for profit.',
#   'score': 28},
#  'espartaco guillermo arenas villarreal': {'query': 'reports on wildlife crime and illegal trade',
#   'score': 55},
#  'josefina julio pichardo reyna': {'query': 'no specific names of individuals or positions are provided.',
#   'score': 44},
#  'josefina elisa solorio ávila': {'query': 'no specific names of individuals or positions are provided.',
#   'score': 44},
#  'josefina wendolin rodrígez zepeda': {'query': 'no specific names of individuals or positions are provided.',
#   'score': 44},
#  'simonova polina petrovna': {'query': 'no specific names of individuals or positions are provided.',
#   'score': 44},
#  'steven giles': {'score': 64, 'query': 'two juveniles'},
#  'troy jenkins': {'score': 64, 'query': 'two juveniles'},
#  'carlos rodriguez': {'query': 'carlos rodriguez', 'score': 100},
#  'alexander beck': {'query': 'alexander bic', 'score': 89},
#  'alexander rice': {'query': 'alexander bic', 'score': 89},
#  'pei chao': {'score': 67, 'query': 'pechi café'},
#  'pamela adams': {'query': 'pamela paaso', 'score': 83},
#  'pamela mason': {'query': 'pamela paaso', 'score': 83},
#  'pamela parks': {'query': 'pamela paaso', 'score': 83},
#  'travis gill': {'score': 74, 'query': 'trigillo'},
#  'emmanuel tessier': {'query': 'emanuele tesoro', 'score': 77},
#  'tomás evelio campos cisneros': {'score': 48,
#   'query': 'customs seizes $3 million worth of counterfeit goods'},
#  'henriette-vanessa leclerc': {'query': 'the united states fish and wildlife service',
#   'score': 53},
#  'akarsh ram': {'score': 76, 'query': 'akbar akram'},
#  "larionova valentina afanas'evna": {'query': 'no output. the article does not mention any names of individuals involved in animal trafficking.',
#   'score': 37},
#  'mark sloan': {'query': 'mark slotkin', 'score': 82},
#  'dr.lic. ana luisa reynoso': {'score': 56,
#   'query': 'seguridad pública de san luis potosí'},
#  'melissa key': {'score': 73, 'query': 'omaliss keo'},
#  'ind.courtney garner': {'query': 'including 27 security screeners',
#   'score': 56},
#  'claudine richard-demers': {'query': 'including 27 security screeners',
#   'score': 56},
#  'claudia esther rentería': {'query': 'including 27 security screeners',
#   'score': 56},
#  'richard herman': {'query': 'richard sheridan', 'score': 87},
#  'vicente claudia tijerina escalante': {'score': 45,
#   'query': 'puedo ver que la procuraduría federal de protección al ambiente'},
#  'alan gates': {'score': 57, 'query': 'ages'},
#  'amy rogers': {'score': 57, 'query': 'ages'},
#  'sean gates': {'score': 67, 'query': 'semarnat'},
#  'lisa giles': {'score': 57, 'query': 'ages'},
#  'amy grimes': {'score': 57, 'query': 'ages'},
#  'emma giles': {'score': 57, 'query': 'ages'},
#  'ann hughes': {'score': 57, 'query': 'ages'},
#  'óliver florencia de la rosa espinosa': {'query': 'la mujer sorprendida con mil huevos de tortuga en el mercado de la viga es la imputada. el nombre de la mujer no se menciona explícitamente en el artículo',
#   'score': 31},
#  'george salinas': {'score': 73, 'query': 'georgy gvasaliya'},
#  'mrs. beth george': {'score': 65, 'query': 'mayor of cape st. george'},
#  'maría cristina camila camacho henríquez': {'score': 40,
#   'query': 'the passenger, a chinese national, who was caught with 740 grams of seahorses'},
#  'peter miller': {'score': 88, 'query': 'peter millroy'},
#  'bernardo espinal de la rosa': {'query': 'el organismo responsable de la protección al ambiente en méxico',
#   'score': 47},
#  'gabrielle harper': {'score': 93, 'query': 'gabriel harper'},
#  'jimmy shea': {'query': 'jimmy kha', 'score': 84},
#  'ind.joaquín modesto de la torre valverde': {'query': 'la información proporcionada no contiene nombres de personas o entidades que hayan sido arrestadas o plead guilty en relación con el tráfico ilegal de vida silvestre. por lo tanto',
#   'score': 30},
#  'paul allen': {'score': 82, 'query': 'paul tallman'},
#  'darío timoteo de la fuente nájera': {'query': 'carlos loret de mola, periodista de el universal.',
#   'score': 52},
#  'arturo ivonne gaona aparicio': {'score': 48,
#   'query': 'the aeropuerto internacional de la ciudad de méxico'},
#  'gerardo itzel de anda madera': {'score': 49,
#   'query': 'with the support of the sedena and policía federal'},
#  'lic. hermelinda rentería': {'score': 52,
#   'query': 'policía federal - división gendarmería'},
#  'francisco javier daniela salas batista': {'score': 25,
#   'query': 'la información proporcionada no contiene nombres de personas o entidades que hayan sido acusadas de delitos ambientales. la noticia se enfoca en la aseguramiento de madera ilegal y la detección de irregularidades en transportistas'},
#  'antonio esperanza canales manzanares': {'score': 34,
#   'query': 'no se encontraron nombres de personas o entidades relacionadas con el tráfico ilegal de madera en el artículo proporcionado. la profepa'},
#  'mariano espartaco cedillo collazo': {'query': 'la información proporcionada no contiene nombres de personas o entidades que hayan sido arrestadas o declarado guilty en relación con el tráfico ilegal de madera. por lo tanto',
#   'score': 29},
#  'mary summers': {'query': 'marc summers', 'score': 92},
#  'marie moreno': {'query': 'arte moreno', 'score': 87},
#  'peng rui': {'query': 'pgr', 'score': 55},
#  'pang rui': {'query': 'pgr', 'score': 55},
#  'shane andrews': {'query': 'wayne andrews', 'score': 85},
#  'wayne sanders': {'query': 'wayne andrews', 'score': 85},
#  'leah pope': {'query': 'at least 16 people', 'score': 59},
#  'camille-caroline lapointe': {'query': 'an min visits lok ma chau control point',
#   'score': 50},
#  'ind.indira victoria mata portillo': {'query': 'an min visits lok ma chau control point',
#   'score': 50},
#  "muhin isidor anatol'evich": {'query': 'an min visits lok ma chau control point',
#   'score': 50},
#  'maría eugenia esmeralda saldaña': {'score': 53,
#   'query': 'secretaría de seguridad ciudadana'},
#  'dana watts': {'score': 74, 'query': 'dan titus'},
#  'francisco morris': {'query': 'francisco moreno merino', 'score': 77},
#  'sean patel': {'score': 67, 'query': 'semarnat'},
#  'samar sant': {'score': 67, 'query': 'semarnat'},
#  'sue martin': {'score': 67, 'query': 'semar'},
#  'shoppemart': {'score': 67, 'query': 'semar'},
#  'samar kata': {'score': 67, 'query': 'semarnat'},
#  'samar tata': {'score': 67, 'query': 'semarnat'},
#  'stephen huang': {'score': 90, 'query': 'stephen shu wang'},
#  'ofelia hermelinda de la torre tórrez': {'score': 26,
#   'query': 'seized 199 pieces of wood and put four people at the disposal of the ministerio público federal. it does not provide any further details about the identities of these individuals or their alleged crimes. therefore'},
#  'caridad pilar briones hernandes': {'query': 'the unnamed individuals who were involved in the illegal wildlife trade and brought the spider monkeys to the progreso international bridge.',
#   'score': 32},
#  'ind.gonzalo emilia gallegos peralta': {'query': 'the unnamed individuals who were involved in the illegal wildlife trade and brought the spider monkeys to the progreso international bridge.',
#   'score': 32},
#  'james hayes': {'score': 88, 'query': 'james t. hayes'},
#  'hua jian guo': {'score': 73, 'query': 'huaqian qu'},
#  'christy ford': {'score': 91, 'query': 'chris ford'},
#  'francisco javier martha bueno villarreal': {'score': 36,
#   'query': 'la información proporcionada es un extracto de una noticia sobre la aseguramiento de madera en rollos ilegales en campeche'},
#  'francisco javier leonor otero polanco': {'query': 'la información que has proporcionado no contiene nombres de personas o instituciones relacionadas con el tráfico ilegal de madera. por lo tanto',
#   'score': 33},
#  'maximiliano josé eduardo varela carvajal': {'score': 28,
#   'query': 'la información proporcionada no contiene nombres de personas o entidades que hayan sido arrestadas o plead guilty a moins que se refieran a la procuraduría federal de protección al ambiente'},
#  'ind.teresa guadalupe girón acosta': {'score': 48,
#   'query': 'international day of the girl child 2018 poster'},
#  'latoya arias': {'query': 'astrophytum asterias', 'score': 62},
#  'andres shaw': {'query': 'fares sabawi', 'score': 70},
#  'kai k ng': {'score': 89, 'query': 'kai kin ng'},
#  'dr.henriette-christiane lachapelle': {'query': 'nicolas garcia, the fbi legal attache office representative in taiwan, who made a rare public appearance at a news conference at the cib’s taipei office.',
#   'score': 29},
#  'jeffery richards': {'query': 'jeff richards', 'score': 90},
#  'jeffrey richards': {'query': 'jeff richards', 'score': 90},
#  'mitchell warren': {'score': 57, 'query': 'name withheld until arraignment'},
#  'thomas cox': {'query': 'thomas choi', 'score': 86},
#  'steven mitchell': {'query': 'steven michael lundblad', 'score': 74},
#  'theresa bennett': {'score': 56, 'query': 'there are no names to output.'},
#  'catherine jones-thorpe': {'score': 56,
#   'query': 'there are no names to output.'},
#  'iván maría del carmen ureña herrera': {'score': 41,
#   'query': 'in securing the animals and requesting documentation from the owner. therefore'},
#  'jorge luis jaime espino de la torre': {'score': 41,
#   'query': 'in securing the animals and requesting documentation from the owner. therefore'},
#  'richard carrillo': {'score': 88, 'query': 'richard parrinello'},
#  'charles stout': {'score': 74, 'query': 'charlie justus'},
#  'judith king': {'query': 'yudith ‘n’', 'score': 70},
#  'judith horn': {'query': 'yudith ‘n’', 'score': 70},
#  'judith yang': {'query': 'yudith ‘n’', 'score': 70},
#  'michael wong': {'score': 96, 'query': 'michael kwong'},
#  'katie cole': {'score': 67, 'query': 'tecolote'},
#  'peter cole': {'score': 67, 'query': 'tecolote'},
#  'terry cole': {'score': 67, 'query': 'tecolote'},
#  'yuan jie': {'score': 88, 'query': 'yuan xie'},
#  'yuan xia': {'score': 88, 'query': 'yuan xie'},
#  'ind.dorothée therrien-fontaine': {'score': 35,
#   'query': 'the person who brought the python to the maritime reptile zoo in dartmouth, whose name is also not mentioned.'},
#  'zhang dan dan': {'score': 74, 'query': 'hoang tan dinh'},
#  'huang dan dan': {'score': 74, 'query': 'hoang tan dinh'},
#  'chang dan dan': {'score': 74, 'query': 'hoang tan dinh'},
#  'hong lan ying': {'score': 74, 'query': 'hoang tan dinh'},
#  'kevin duval': {'query': 'kevin duc vu', 'score': 78},
#  'donald kemp': {'query': 'donald trump', 'score': 78},
#  'francisco javier omar rentería tijerina': {'query': "the federal prosecutor's office for environmental protection",
#   'score': 46},
#  'dr.david sims': {'score': 58, 'query': 'dos individuos más'},
#  'ming chang': {'query': 'kam wing chan', 'score': 78},
#  'gloria martinez': {'score': 77, 'query': 'hugo r. martinez'},
#  'george martinez': {'score': 77, 'query': 'hugo r. martinez'},
#  'arthur martinez': {'score': 77, 'query': 'hugo r. martinez'},
#  'dawn cruz': {'score': 82, 'query': 'dan crum'},
#  'dana cruz': {'score': 82, 'query': 'dan crum'},
#  'luisa valencia': {'score': 76, 'query': 'luis eudoro valencia'},
#  'louis valencia': {'score': 76, 'query': 'luis eudoro valencia'},
#  'wayne blevins': {'query': 'bruce wayne bivins', 'score': 71},
#  'robert sanders dvm': {'score': 49, 'query': 'home depot s. de r.l de c.v.'},
#  'heather porter dvm': {'score': 49, 'query': 'home depot s. de r.l de c.v.'},
#  'flavio aida mayorga castro': {'score': 53,
#   'query': "arnold jan d'ailly, mayor of amsterdam"},
#  'roland lavoie-marcotte': {'score': 53,
#   'query': "arnold jan d'ailly, mayor of amsterdam"},
#  'maria torres': {'query': 'mariza toet', 'score': 78},
#  'maria stokes': {'query': 'mariza toet', 'score': 78},
#  'sahil sama': {'query': 'sal amato', 'score': 74},
#  'lee thomas': {'query': 'feel free to ask', 'score': 62},
#  'dr.gerardo ignacio bernal casanova': {'query': 'the passenger was not named in the article, so their name is not available.',
#   'score': 43},
#  "evpraksija gennadievna terent'eva": {'query': 'the passenger was not named in the article, so their name is not available.',
#   'score': 43},
#  'michael friedman': {'score': 81, 'query': 'michael flikkema'},
#  'ian king': {'query': 'iwan kolopaking', 'score': 70},
#  'ian lang': {'query': 'iwan kolopaking', 'score': 70},
#  'jos reina de la torre cisneros': {'query': 'no se puede extraer ningún nombre de la información proporcionada. sin embargo',
#   'score': 44},
#  'aaron jones': {'query': 'aaron jones', 'score': 100},
#  'matthew valenzuela': {'score': 73, 'query': 'maite azuela'},
#  'melanie valenzuela': {'score': 73, 'query': 'maite azuela'},
#  'maria nguyen': {'query': 'mai nguyen', 'score': 91},
#  'marie nguyen': {'query': 'mai nguyen', 'score': 91},
#  'jean pelletier': {'score': 73, 'query': 'jeannot pellerin'},
#  'daniel flores': {'query': 'manuel flores', 'score': 85},
#  'samuel flores': {'query': 'manuel flores', 'score': 85},
#  'angela flores': {'query': 'manuel flores', 'score': 85},
#  'amanda gomez': {'query': 'felix armando luna gomez', 'score': 67},
#  'charlotte jones': {'query': 'charlotte jones', 'score': 100},
#  'shane barber': {'score': 80, 'query': 'shane rosberg'},
#  'shane romero': {'score': 80, 'query': 'shane rosberg'},
#  'shane foster': {'score': 80, 'query': 'shane rosberg'},
#  'maría del carmen armenta': {'query': 'pat freeling, a department warden',
#   'score': 56},
#  'xiao dong mei': {'query': 'xiao dong qin', 'score': 85},
#  'jeffrey burton dds': {'score': 44,
#   'query': 'jeffrey o. baldwin, houston cbp director of field operations'},
#  'william hines': {'query': 'william mcginness', 'score': 80},
#  'william miles': {'query': 'william mcginness', 'score': 80},
#  'william mcgee': {'query': 'william mcginness', 'score': 80},
#  'amy hutchinson': {'query': 'jeramy hutchison', 'score': 87},
#  'ryan blair': {'score': 100, 'query': 'ryan blair'},
#  'grace mcdaniel': {'score': 89, 'query': 'grace daniels'},
#  'rachel daniels': {'score': 89, 'query': 'grace daniels'},
#  'agustín daniela rodarte sandoval': {'query': 'agustín radilla suástegui, comandante de la 30ª zona militar.',
#   'score': 50},
#  'guo jian hua': {'score': 72, 'query': 'guo tuan zhou'},
#  'anthony tran': {'score': 72, 'query': 'oanh thi tran'},
#  'cynthia tran': {'score': 72, 'query': 'oanh thi tran'},
#  "g-n eliseev valentin vital'evich": {'score': 37,
#   'query': 'the names of the guilty parties in this case are not explicitly mentioned in the article. however'},
#  'ishita deo': {'query': 'el visitado', 'score': 67},
#  'joy tran': {'score': 80, 'query': 'to tran'},
#  'dr.homero andrea miramontes carrera': {'query': 'the 20-year-old female u.s. citizen driver who attempted to smuggle the spider monkeys across the border.',
#   'score': 37},
#  'stéphanie racine-fortier': {'score': 52,
#   'query': 'stop human trafficking—it’s modern slavery'},
#  'dr.cristobal esquibel preciado': {'query': 'por no acreditarse su legal procedencia.',
#   'score': 55},
#  'aleksandrova evdokija andreevna': {'query': 'email address and social media handles for feedback and queries',
#   'score': 47},
#  'hong xie': {'score': 80, 'query': 'hong hui xie'},
#  'jeff smith': {'score': 73, 'query': 'jeff minchow'},
#  'henriette-jeannine fortier': {'query': 'the owner of the circo, who was not named in the article.',
#   'score': 44},
#  'dr.sr(a). antonia tijerina': {'query': 'threats faced by the species and conservation efforts in india',
#   'score': 43},
#  'christiane jean-fortin': {'query': 'threats faced by the species and conservation efforts in india',
#   'score': 43},
#  'bernardo ilse contreras tijerina': {'query': 'threats faced by the species and conservation efforts in india',
#   'score': 43},
#  "terent'eva naina leonidovna": {'query': 'threats faced by the species and conservation efforts in india',
#   'score': 43},
#  'elsa delia fonseca partida': {'query': 'threats faced by the species and conservation efforts in india',
#   'score': 43},
#  'strelkova aleksandra leonidovna': {'query': 'threats faced by the species and conservation efforts in india',
#   'score': 43},
#  'dr.teodoro renato merino longoria': {'query': 'the owner of the centro de almacenamiento y transformación',
#   'score': 46},
#  'ind.tov. vladimirov viktorin haritonovich': {'query': "east valley teen assaults: photos: gilbert police asking for help identifying victims, suspects in teen violence cases. chief michael soelberg shared photos and videos of four cases gilbert police are investigating involving teen violence and the 'gilbert goons' gang.",
#   'score': 21},
#  'zhao feng': {'query': 'jin zhao feng', 'score': 82},
#  'jiao feng': {'query': 'jin zhao feng', 'score': 82},
#  'rosalie pilon': {'query': 'el responsable inspeccionado', 'score': 54},
#  'joel robinson': {'query': 'el responsable inspeccionado', 'score': 54},
#  'dr.john wade': {'query': 'dr. john waldrop', 'score': 79},
#  'dustin collins': {'query': 'dustin hollingsworth', 'score': 76},
#  'prorepair': {'score': 67, 'query': 'pepfar'},
#  'olivia terrance': {'query': 'olivia terrance', 'score': 100},
#  'cecilia maría cristina espinoza grijalva': {'score': 41,
#   'query': 'veracidad y la calidad de la información es estricta responsabilidad de la dependencia'},
#  'lori sexton': {'score': 70, 'query': 'lo siento'},
#  'haley rush': {'query': 'harley circus', 'score': 78},
#  'robin huerta': {'score': 54, 'query': 'hiroki uetsuki'},
#  'heidi tucker': {'score': 54, 'query': 'hiroki uetsuki'},
#  'henri brunet': {'score': 54, 'query': 'hiroki uetsuki'},
#  'heidi peters': {'score': 54, 'query': 'hiroki uetsuki'},
#  'henri dupuis': {'score': 54, 'query': 'hiroki uetsuki'},
#  'charvi desai': {'score': 54, 'query': 'hiroki uetsuki'},
#  'robin austin': {'score': 54, 'query': 'hiroki uetsuki'},
#  'henri doucet': {'score': 54, 'query': 'hiroki uetsuki'},
#  'alejandro serafín zepeda linares': {'score': 43,
#   'query': "casey durst, cbp's director of field operations in baltimore"},
#  'maryse st-pierre-fortier': {'score': 43,
#   'query': "casey durst, cbp's director of field operations in baltimore"},
#  'kara rodriguez': {'query': 'karla rodríguez', 'score': 90},
#  'tristan roberge': {'query': 'transportista sin nombre', 'score': 62},
#  'kelly hernandez': {'score': 72, 'query': 'kelsy hernandez quintana'},
#  'amanda sullivan': {'query': 'hamada suisan co.', 'score': 71},
#  'miguel mentzel': {'query': 'miguel vazquez pimentel', 'score': 70},
#  'miguel vasquez': {'query': 'miguel vazquez pimentel', 'score': 70},
#  'sara espartaco romero de la o': {'score': 48,
#   'query': 'la profepa aseguró un ejemplar de cachorro de león africano'},
#  'claudio maría del carmen jaime': {'query': 'claudia sheinbaum pardo, jefa de gobierno de la ciudad de méxico.',
#   'score': 45},
#  'martin daniels': {'query': 'harlin daniels', 'score': 86},
#  'camila mercedes prado alarcón': {'score': 51,
#   'query': 'escamilla was released from jail on sunday'},
#  'estela alejandro pichardo quesada': {'score': 51,
#   'query': 'escamilla was released from jail on sunday'},
#  'militsa aleksandrovna shubina': {'score': 51,
#   'query': 'escamilla was released from jail on sunday'},
#  'josé carlos josé maría vaca de la garza': {'query': 'se aseguró 8.9 metros cúbicos de madera aserrada del género pino',
#   'score': 47},
#  'esther olivo de la rosa': {'score': 59,
#   'query': 'ministerio publico de la federacion'},
#  'kyle miller': {'query': 'lyle mcgillvray', 'score': 69},
#  'claudine charest': {'score': 69, 'query': 'including whales'},
#  'dr.nancy josefina de la torre ibarra': {'score': 45,
#   'query': 'no hay ningún nombre específico que pueda extraer. sin embargo'},
#  'dr.estela alejandro linares guillen': {'score': 36,
#   'query': 'for two hours as the pair allegedly kayaked into the ocean and used scuba gear to collect 55 abalone'},
#  'lawrence riley': {'query': 'lawrence treigle jr.', 'score': 79},
#  'joshua davila': {'query': 'joshua david moltzan', 'score': 79},
#  'jeffrey chung': {'score': 80, 'query': 'jeffrey jace hunt'},
#  'jorge clark': {'score': 75, 'query': 'jorge caraveo'},
#  'jorge drake': {'score': 75, 'query': 'jorge caraveo'},
#  'john branch': {'query': 'john birch', 'score': 86},
#  'bruce allen': {'query': 'bruce apple', 'score': 82},
#  'josé maría serna': {'query': 'josé maría "n"', 'score': 83},
#  'leonard buchanan': {'score': 67, 'query': 'leonard muamba kanda'},
#  'leonard adams': {'score': 67, 'query': 'leonard muamba kanda'},
#  'leonard mcmillan': {'score': 67, 'query': 'leonard muamba kanda'},
#  'marvin harris': {'query': 'marvin harrison jr.', 'score': 84},
#  'laura sparks': {'score': 61, 'query': 'lonchura sp'},
#  'laura spears': {'score': 61, 'query': 'lonchura sp'},
#  'laura bishop': {'score': 61, 'query': 'lonchura sp'},
#  'laura joseph': {'score': 61, 'query': 'lonchura sp'},
#  'anthony burgess': {'score': 65, 'query': 'anthony bucci, press officer'},
#  'mark khan': {'score': 74, 'query': 'nazir khan'},
#  'anna khan': {'score': 74, 'query': 'nazir khan'},
#  'kara khan': {'score': 74, 'query': 'nazir khan'},
#  'noah khan': {'score': 74, 'query': 'nazir khan'},
#  'sara khan': {'score': 74, 'query': 'nazir khan'},
#  'maurice bélanger': {'score': 62, 'query': 'murciélago'},
#  'maurice langlois': {'score': 62, 'query': 'murciélago'},
#  'loretta kelly': {'query': 'loretta e. lynch', 'score': 76},
#  'joshua thomas': {'query': 'toshiyuki komatsu', 'score': 60},
#  'héctor adalberto cadena vergara': {'score': 56,
#   'query': 'héctor de mauleón, periodista de en tercera persona.'},
#  'maria golden': {'query': 'ari b. goldenberg', 'score': 69},
#  'dr.francisco javier tania leiva serrato': {'score': 27,
#   'query': 'that the owner of the animal claimed to have found it in the street and taken it home to protect it. there is no mention of any legal proceedings or penalties imposed on the owner. therefore'},
#  'dr.marisela leticia porras gonzález': {'query': 'have been fired after a federal investigation found "multiple instances" of improper security screening at the site. 2 women killed',
#   'score': 31},
#  'esther francisco javier cepeda puente': {'score': 29,
#   'query': 'any other individuals involved in the supply chain of the illegal wildlife products, such as those who poached the elephants or smuggled the products into the country.'},
#  'margarita ernesto navarrete valverde': {'query': 'have been fired after a federal investigation found "multiple instances" of improper security screening at the site. 2 women killed',
#   'score': 31},
#  'ind.adela herrera de la torre': {'query': 'inspectores de la protectora de bosques del estado de méxico',
#   'score': 47},
#  'joseph nicholson': {'score': 90, 'query': 'joe nicholson'},
#  'jerome nicholson': {'score': 90, 'query': 'joe nicholson'},
#  'timothée desrosiers': {'score': 57, 'query': 'five of them undersized'},
#  'laura graciela elizondo villareal': {'query': 'lo que podría ser considerado como una violación ambiental.',
#   'score': 46},
#  "dr.seliverstova oksana il'inichna": {'query': 'lo que podría ser considerado como una violación ambiental.',
#   'score': 46},
#  'dr.dolores rodolfo salazar mondragón': {'query': 'la pgr y los pobladores del ejido son las únicas partes mencionadas en el artículo. por lo tanto',
#   'score': 39},
#  'maría del carmen karla castillo molina': {'query': 'méxico. no se mencionan nombres de personas o entidades específicas que hayan participado en la trata ilegal de animales. por lo tanto',
#   'score': 33},
#  'justin andrews': {'query': 'justin andrew wilke', 'score': 79},
#  'scott roach': {'score': 83, 'query': 'scott murdoch.'},
#  'josé luis robles de la rosa': {'query': 'los inspectores federales de la profepa',
#   'score': 61},
#  'chad robertson': {'query': 'chad dotson', 'score': 80},
#  'ing. virginia aranda': {'score': 62,
#   'query': 'brigada de vigilancia animal'},
#  'francis gray': {'score': 81, 'query': 'francis gurahoo'},
#  'kevin tran': {'query': 'kevin tran', 'score': 100},
#  'dalia concepción': {'score': 73, 'query': 'yandie concepcion'},
#  'claude laplante': {'score': 65, 'query': 'alcaldía de tlalpan'},
#  'patrick sherman': {'score': 90, 'query': 'patrick sheridan'},
#  'ind.marco antonio estévez rojas': {'score': 51,
#   'query': 'objectives and impact of these programs'},
#  'zhao fan': {'query': 'zapopan', 'score': 67},
#  'zhao dan': {'query': 'zapopan', 'score': 67},
#  'zhao nan': {'query': 'zapopan', 'score': 67},
#  'zhao yan': {'query': 'zapopan', 'score': 67},
#  'dong wei': {'query': 'yundong wei', 'score': 84},
#  'jesse farley': {'score': 82, 'query': 'jesse earl'},
#  'jesse arnold': {'score': 82, 'query': 'jesse earl'},
#  'stéphane therrien': {'score': 100, 'query': 'stéphane therrien'},
#  'simone charette': {'query': 'simon chee thye chaw', 'score': 63},
#  'amanda pena': {'query': 'la monda peluda', 'score': 69},
#  'jaime martin': {'query': 'jaime villamarin', 'score': 79},
#  'evan mccarthy': {'score': 74, 'query': 'eamon mcarthur'},
#  'esparta sandra montero palomino': {'score': 49,
#   'query': 'the procuraduría federal de proteccion al ambiente'},
#  'brian miller': {'query': 'brian miller', 'score': 100},
#  'carlos king': {'score': 80, 'query': 'carlos "g"'},
#  'carlos yang': {'score': 80, 'query': 'carlos "g"'},
#  'carlos wong': {'score': 80, 'query': 'carlos "g"'},
#  'barry monroe': {'query': 'barry roe', 'score': 86},
#  'tara kala': {'score': 74, 'query': 'tamba kaba'},
#  'teresa gonzalez': {'score': 64, 'query': 'nancy teresa gonzalez de barberi'},
#  'dr.teresa gonzalez': {'score': 64,
#   'query': 'nancy teresa gonzalez de barberi'},
#  'lic. josé emilio pantoja': {'query': 'méxico. por lo tanto', 'score': 59},
#  'nicole stanton': {'query': 'méxico. por lo tanto', 'score': 59},
#  'lance gregory': {'score': 85, 'query': 'logan gregory'},
#  'dylan gregory': {'score': 85, 'query': 'logan gregory'},
#  'cao nan': {'score': 77, 'query': 'conanp'},
#  'graciela timoteo lovato de la torre': {'score': 40,
#   'query': "subscribe to the daily mail's newsletter or email alerts to receive updates on their latest stories."},
#  'henriette renaud': {'score': 69, 'query': 'sariette groenewald'},
#  'ind.roland therrien': {'query': 'wing quon enterprises ltd.', 'score': 55},
#  'ing. sonja hendriks': {'query': 'wing quon enterprises ltd.', 'score': 55},
#  'silvano israel cepeda hernandes': {'query': 'the anonymous tipster who reported seeing the tiger in the abandoned house',
#   'score': 42},
#  "viktorija maksimovna krasil'nikova": {'score': 38,
#   'query': 'it is not appropriate to make assumptions or accusations without proper evidence. additionally'},
#  'jason mora': {'score': 75, 'query': 'sonora'},
#  'mark aguilar': {'query': 'mark auliya', 'score': 78},
#  'patricio alicia briones negrón': {'score': 45,
#   'query': 'participation of local communities and schools in these programs'},
#  'marco antonio laureano olivas': {'score': 45,
#   'query': 'participation of local communities and schools in these programs'},
#  'patricio elias granados villarreal': {'query': 'karim daoues, specialist in reptiles and responsible for "la ferme tropicale"',
#   'score': 44},
#  "ol'ga el'darovna mel'nikova": {'query': 'el organismo responsable de la protección al ambiente en méxico',
#   'score': 47},
#  'roberto josé carlos loera corral': {'score': 37,
#   'query': 'foy said. wang was booked into mendocino county jail for possession of abalone for commercial sale'},
#  'catherine auger-beauregard': {'score': 51,
#   'query': 'kathy crane, owner of yerba buena nursery'},
#  'jonathan richer-beauregard': {'score': 51,
#   'query': 'kathy crane, owner of yerba buena nursery'},
#  'vanessa rondeau': {'query': 'vanessa rondeau', 'score': 100},
#  'dr.conchita francisco javier henríquez zapata': {'query': 'united states v. thomas h. faria: a case involving the discharge of industrial wastewater from a manufacturing facility without a permit, in violation of the clean water act.',
#   'score': 29},
#  'sara cuevas': {'query': 'oscar cueva', 'score': 82},
#  'isabel santiago palacios gonzales': {'score': 32,
#   'query': 'visit the daily mail website directly at [www.dailymail.co.uk](http://www.dailymail.co.uk) and browse through their latest articles.'},
#  'adela liliana contreras garica': {'score': 32,
#   'query': 'visit the daily mail website directly at [www.dailymail.co.uk](http://www.dailymail.co.uk) and browse through their latest articles.'},
#  'alfonso leal': {'score': 73, 'query': 'alfonso "s"'},
#  'john ross': {'query': 'john h. cross iii', 'score': 69},
#  'lin chao': {'score': 64, 'query': 'oleg n. chakov'},
#  'dr.elaine austin': {'query': 'renaissance aquatics, inc.', 'score': 59},
#  'rick park': {'query': 'rick earl', 'score': 78},
#  'rick pena': {'query': 'rick earl', 'score': 78},
#  'rick hall': {'query': 'rick earl', 'score': 78},
#  'eric neal': {'query': 'rick earl', 'score': 78},
#  'david summers': {'query': 'david sommers', 'score': 92},
#  'jacob bennett': {'score': 83, 'query': 'jacob menne'},
#  'maría elena luz venegas arevalo': {'score': 52,
#   'query': 'empacadora selecta los ángeles s.a. de c.v.'},
#  'ind.zhang lin': {'query': 'indian pangolin', 'score': 71},
#  "ind.tat'jana filippovna kalinina": {'score': 48,
#   'query': 'xiao yang, 41, of elk grove, california'},
#  'isakova faina feliksovna': {'score': 48,
#   'query': 'xiao yang, 41, of elk grove, california'},
#  'ind.tov. orehova ija nikiforovna': {'score': 48,
#   'query': 'xiao yang, 41, of elk grove, california'},
#  'adrian tran': {'query': 'adrián “n”', 'score': 70},
#  'adrian long': {'query': 'adrián “n”', 'score': 70},
#  'adrian nash': {'query': 'adrián “n”', 'score': 70},
#  'adrian cain': {'query': 'adrián “n”', 'score': 70},
#  'adrian bond': {'query': 'adrián “n”', 'score': 70},
#  'adrian neal': {'query': 'adrián “n”', 'score': 70},
#  'adrian mann': {'query': 'adrián “n”', 'score': 70},
#  'richard king': {'query': 'richard kipsang', 'score': 89},
#  'li na': {'query': 'na', 'score': 57},
#  'wu na': {'query': 'na', 'score': 57},
#  'gu na': {'query': 'na', 'score': 57},
#  'xu na': {'query': 'na', 'score': 57},
#  'ma na': {'query': 'na', 'score': 57},
#  'hu na': {'query': 'na', 'score': 57},
#  'mo na': {'query': 'na', 'score': 57},
#  'ind.elena patricio almaraz durán': {'score': 41,
#   'query': 'se menciona que el inspeccionado no presentó la autorización emitida por la semarnat'},
#  'sun li hua': {'score': 74, 'query': 'su-jan lin chuang'},
#  'misha roy': {'query': 'masphal kry', 'score': 70},
#  'rasha roy': {'query': 'masphal kry', 'score': 70},
#  'dr.adalberto maría luisa portillo jurado': {'query': "medical examiner rules queen creek teen preston lord’s death a ‘homicide’. the maricopa county m.e.'s office says the report is complete and currently under legal review.",
#   'score': 29},
#  'mary cooper': {'score': 80, 'query': 'gary l. cooper'},
#  'gary hooper': {'score': 80, 'query': 'gary l. cooper'},
#  'carl cooper': {'score': 80, 'query': 'gary l. cooper'},
#  'francisca dalia de león olivas': {'query': 'la información proporcionada es un comunicado de prensa sobre la aseguridad de un ejemplar de león africano en colima',
#   'score': 38},
#  'erin johnson': {'query': 'sterling johnson', 'score': 86},
#  'jeffrey love': {'query': 'jeffrey lowe', 'score': 92},
#  'jeffrey howe': {'query': 'jeffrey lowe', 'score': 92},
#  'ana mariano delgadillo': {'query': 'el banco interamericano de desarrollo',
#   'score': 54},
#  'estela quintero arroyo': {'query': 'el banco interamericano de desarrollo',
#   'score': 54},
#  'bianca naranjo badillo': {'query': 'el banco interamericano de desarrollo',
#   'score': 54},
#  'samuel vargas': {'query': 'yamel armas', 'score': 75},
#  'pamela vargas': {'query': 'yamel armas', 'score': 75},
#  'heather cortez': {'query': 'the court', 'score': 70},
#  'heather curtis': {'query': 'the court', 'score': 70},
#  'matthew cortez': {'query': 'the court', 'score': 70},
#  'stephen curtis': {'query': 'the court', 'score': 70},
#  'matthew curtis': {'query': 'the court', 'score': 70},
#  'charlotte-catherine arsenault': {'score': 42,
#   'query': 'the man who attempted to lasso the tiger in the video shared on social media.'},
#  'aldo francisco javier villanueva palacios': {'score': 25,
#   'query': 'united states v. matthaios fafalios et al.: a case involving the construction of an illegal bypass to allow for the discharge of oily bilge waste overboard a ship, in violation of apps and obstruction of justice.'},
#  "dr.tat'jana al'bertovna konstantinova": {'query': 'who were traveling to the united states for a concert tour. it is reported that all seven bows had documentation stating that they did not contain any elements of elephant ivory',
#   'score': 28},
#  'laetitia thériault': {'score': 65, 'query': 'bletilla striata'},
#  'william estrada': {'score': 65, 'query': 'bletilla striata'},
#  'tiya srivastava': {'score': 65, 'query': 'bletilla striata'},
#  'christelle fillion-turcotte': {'query': 'customs arrests 52 people for buying illicit cigarettes',
#   'score': 44},
#  'jacques desbiens-lafontaine': {'query': 'customs seizes $11.8 million worth of ketamine',
#   'score': 47},
#  'phillip lang': {'score': 92, 'query': 'phillip land'},
#  'antonio salvador sauceda bustamante': {'score': 35,
#   'query': 'two individuals, one who was caught with a live crocodile and another who was found with 17 armadillos in taxidermy.'},
#  'maximiliano josé carlos montalvo aguilera': {'query': 'la información proporcionada no contiene nombres de personas o entidades que hayan sido acusadas de delitos relacionados con la tala ilegal. por lo tanto',
#   'score': 31},
#  'diana estela miramontes navarrete': {'query': "medical examiner rules queen creek teen preston lord’s death a ‘homicide’. the maricopa county m.e.'s office says the report is complete and currently under legal review.",
#   'score': 29},
#  'charles wood': {'query': 'charles good', 'score': 92},
#  'charles hood': {'query': 'charles good', 'score': 92},
#  'isaac marco antonio ruelas gutiérrez': {'query': 'united states v. nancy m. stein et al.: a case involving bank fraud and the improper handling of hazardous materials, including corrosive materials and fake invoices.',
#   'score': 30},
#  'lori dixon': {'score': 67, 'query': 'lidio'},
#  'luis dixon': {'score': 67, 'query': 'lidio'},
#  'li dong': {'score': 67, 'query': 'lidio'},
#  'julie dion': {'score': 67, 'query': 'lidio'},
#  'élise dion': {'score': 67, 'query': 'lidio'},
#  'maría del carmen beatriz treviño anguiano': {'score': 27,
#   'query': 'that the owner of the animal claimed to have found it in the street and taken it home to protect it. there is no mention of any legal proceedings or penalties imposed on the owner. therefore'},
#  'mayte daniela caraballo de anda': {'query': 'foy said. the deputies found two wet duffel bags containing fresh abalone in the back seat and contacted fish and game warden don powers',
#   'score': 31},
#  'estefanía adalberto quintana granados': {'score': 42,
#   'query': 'estaré encantado de ayudarte en lo que pueda. ¿en qué puedo ayudarte hoy?'},
#  'john black': {'query': 'john blick jr.', 'score': 78},
#  'john blair': {'query': 'john blick jr.', 'score': 78},
#  'mr. john liu': {'query': 'hon kit "john" lau', 'score': 60},
#  'miguel ángel arturo campos': {'score': 77,
#   'query': 'miguel angel campo sr.'},
#  'alex marshall': {'query': 'azulejo mariposa', 'score': 62},
#  'paul marsh': {'query': 'azulejo mariposa', 'score': 62},
#  'paul arias': {'query': 'azulejo mariposa', 'score': 62},
#  'paul marshall': {'query': 'azulejo mariposa', 'score': 62},
#  'julie rios': {'query': 'azulejo mariposa', 'score': 62},
#  'alejandro harris': {'query': 'azulejo mariposa', 'score': 62},
#  'tan hao': {'query': 'bot van ho', 'score': 71},
#  'dolores prieto': {'score': 67, 'query': 'dolores barrientos alemán'},
#  'william dionne': {'score': 75, 'query': 'william d. weinreb'},
#  'william lemire': {'score': 75, 'query': 'william d. weinreb'},
#  'lisa todd': {'score': 50, 'query': 'ltd'},
#  'joel todd': {'score': 50, 'query': 'ltd'},
#  'kyle todd': {'score': 50, 'query': 'ltd'},
#  'melissa caldwell': {'query': 'melvin t. caldwell, jr.', 'score': 68},
#  'carlos dominguez': {'query': 'carlos domínguez', 'score': 94},
#  'ruth nguyen': {'score': 80, 'query': 'cuu thi nguyen'},
#  'marilyn osborne': {'score': 73, 'query': 'marty lynn bone'},
#  'jose pena': {'query': 'sedena', 'score': 67},
#  'jose dean': {'query': 'sedena', 'score': 67},
#  'sean dean': {'query': 'sedena', 'score': 67},
#  'seth pena': {'query': 'sedena', 'score': 67},
#  'robert key': {'query': 'robert keszey', 'score': 87},
#  'monica herrera': {'query': 'policía federal', 'score': 62},
#  'alicia dyer': {'query': 'policía federal', 'score': 62},
#  'alicia herrera': {'query': 'policía federal', 'score': 62},
#  'olivia herrera': {'query': 'policía federal', 'score': 62},
# ...
#   'score': 54},
#  'cristobal asunción barrientos niño': {'query': 'ni con los informes médicos veterinarios presentados para determinar su condición de salud. en ese sentido',
#   'score': 36},
#  'anita young': {'score': 74, 'query': 'tumani a. younge'},
#  'maria young': {'score': 74, 'query': 'tumani a. younge'},
#  'carl moss': {'score': 80, 'query': 'carlos'},
#  'mtro. amelia miranda': {'query': 'the " familia michoacana" drug cartel',
#   'score': 53},
#  'albert orr': {'score': 80, 'query': 'alberto "o".'},
#  'edward klein': {'query': 'edward n. levine', 'score': 79},
#  'chris simmons': {'query': 'his sons', 'score': 76},
#  'dr.maría del carmen zeferino arreola márquez': {'query': 'si necesitas ayuda para encontrar información sobre un tema en particular o para realizar una tarea específica',
#   'score': 38},
#  'cody gordon': {'query': 'pico gordo', 'score': 76},
#  'rick gordon': {'query': 'pico gordo', 'score': 76},
#  'eric gordon': {'query': 'pico gordo', 'score': 76},
#  'humberto longoria coronado': {'score': 50,
#   'query': 'xuzhou-based import and export corporation.'},
#  'thomas-roland bertrand': {'score': 51,
#   'query': 'global plywood and lumber trading llc'},
#  'omar josé carlos santana partida': {'query': 'sin mencionar los nombres de los detenidos o los manifestantes. por lo tanto',
#   'score': 43},
#  'ind.paul pierce': {'query': 'byron paul pitre', 'score': 71},
#  'guy-andré st-onge': {'score': 49, 'query': 'foy said. on feb. 12'},
#  'ann moody': {'score': 67, 'query': 'nobody'},
#  'jon moody': {'score': 67, 'query': 'nobody'},
#  'cheryl sims': {'query': 'chief roy stump', 'score': 62},
#  'cheryl simpson': {'query': 'chief roy stump', 'score': 62},
#  'cheryl kemp': {'query': 'chief roy stump', 'score': 62},
#  'frank mcgrath': {'query': 'frank mctighe', 'score': 77},
#  'frank michael': {'query': 'frank mctighe', 'score': 77},
#  'maría eugenia clemente alemán rosario': {'score': 49,
#   'query': 'el mono araña fue encontrado dentro de un taller mecánico'},
#  "dr.valentina gennad'evna smirnova": {'query': 'tom cash, special agent in charge of the drug enforcement administration in florida',
#   'score': 40},
#  'mishina antonina konstantinovna': {'query': 'tom cash, special agent in charge of the drug enforcement administration in florida',
#   'score': 40},
#  'maría elena teodoro santiago rico': {'score': 43,
#   'query': 'alesia soltanpanah, executive director of world animal protection u.s.'},
#  "tov. jakusheva agaf'ja stanislavovna": {'query': 'tom cash, special agent in charge of the drug enforcement administration in florida',
#   'score': 40},
#  'cynthia genaro romo quintana': {'query': 'tom cash, special agent in charge of the drug enforcement administration in florida',
#   'score': 40},
#  'catherine charette-chartrand': {'query': 'tom cash, special agent in charge of the drug enforcement administration in florida',
#   'score': 40},
#  'alevtina fedorovna dmitrieva': {'query': 'tom cash, special agent in charge of the drug enforcement administration in florida',
#   'score': 40},
#  'brittney garcia': {'score': 80, 'query': 'brittney marcum'},
#  'paul stewart': {'score': 89, 'query': 'paul c. stewart'},
#  'lauren le': {'query': 'lauren lowe', 'score': 90},
#  'dr.keith fleming': {'query': 'keith fleming', 'score': 90},
#  'oda bauer': {'score': 73, 'query': 'rolf d. bauer'},
#  'xiong xia': {'score': 76, 'query': 'xionwei xiao'},
#  'renato marisela vigil coronado': {'query': 'no puedo extraer nombres de la información proporcionada.',
#   'score': 47},
#  'esparta mercedes ferrer villanueva': {'query': 'researchers at mcmaster find an “extensive,” two-year review of covid-19 in schools and daycares has revealed',
#   'score': 36},
#  'maría elena esteban medina carrera': {'query': 'researchers at mcmaster find an “extensive,” two-year review of covid-19 in schools and daycares has revealed',
#   'score': 36},
#  'dorothée martineau': {'query': 'authors of the article.', 'score': 60},
#  'lakshit reddy': {'score': 80, 'query': 'vamshi reddy'},
#  'elakshi reddy': {'score': 80, 'query': 'vamshi reddy'},
#  'ing. socorro de la rosa': {'score': 56,
#   'query': 'the inspectors federales de la profepa'},
#  'gregory fletcher': {'score': 84, 'query': 'george fletcher'},
#  'tan dan dan': {'score': 64, 'query': 'tran dinh tuan vu'},
#  'tan huan': {'score': 64, 'query': 'tran dinh tuan vu'},
#  'tan li juan': {'score': 64, 'query': 'tran dinh tuan vu'},
#  'fateh butala': {'query': 'matehuala', 'score': 76},
#  'federico de anda alvarez': {'query': 'la profepa aseguró cuatro ejemplares de fauna silvestre',
#   'score': 46},
#  'natividad federico mendoza guajardo': {'query': 'nadia, víctima de desaparición mencionada en el artículo.',
#   'score': 51},
#  'alexis cox': {'query': 'jalisco', 'score': 71},
#  'erin webster': {'query': 'derrin b. webster', 'score': 83},
#  'joe williams': {'score': 72, 'query': 'joe willmorth'},
#  'eric nicolás casanova': {'query': 'zoológico nicolás bravo', 'score': 59},
#  'ind.nicholas braun': {'query': 'zoológico nicolás bravo', 'score': 59},
#  'mark chang': {'score': 89, 'query': 'ma chang'},
#  'mary chang': {'score': 89, 'query': 'ma chang'},
#  'michael bryant': {'query': 'michael bryant', 'score': 100},
#  'nathalie marchand': {'score': 61, 'query': 'nationalwide star canada corp.'},
#  'noël couture': {'score': 67, 'query': 'no output.'},
#  'ryan austin': {'score': 78, 'query': 'ryan justice'},
#  'cornelio marcela sepúlveda solorzano': {'query': 'no hay nombres de personas mencionadas en el artículo que puedan ser extraídos. por lo tanto',
#   'score': 39},
#  'devin mullins': {'score': 92, 'query': 'kevin mullins'},
#  'tong cheng': {'score': 67, 'query': 'teo boon ching'},
#  'indira clemente jaime vargas': {'score': 46,
#   'query': 'collaboration with other enforcement agencies and organizations'},
#  'eleonora semenovna semenova': {'score': 51,
#   'query': 'el conductor del camión, cuyo nombre no se menciona.'},
#  'angel cortez': {'score': 64, 'query': 'el ocelote'},
#  'michel cloutier': {'score': 64, 'query': 'el ocelote'},
#  'marcel cloutier': {'score': 64, 'query': 'el ocelote'},
#  'constance morissette-mercier': {'query': 'commissioner of customs and excise expresses deep regret over death of a senior customs officer',
#   'score': 37},
#  'aradhya rao': {'score': 67, 'query': 'dharanidhar boro'},
#  'darren collins': {'query': 'darren paolini', 'score': 79},
#  'nathalie couture-renaud': {'query': 'the output would be na.', 'score': 53},
#  'valerij otto b.a.': {'query': 'the output would be na.', 'score': 53},
#  'henriette godin-arsenault': {'query': 'the person who tried to bring 1,200 eggs of the giant african snail into the country',
#   'score': 39},
#  'scott carpenter': {'score': 88, 'query': 'scott carpenter, jr.'},
#  'derrick allen': {'query': 'merreck allen', 'score': 85},
#  'jim jensen': {'query': 'jim justice', 'score': 67},
#  'jie jie': {'query': 'jim justice', 'score': 67},
#  'jin jie': {'query': 'jim justice', 'score': 67},
#  'ernesto blanca de la o alva': {'query': 'el presunto responsable violó el artículo 122 fracción xxii de la ley general de vida silvestre',
#   'score': 39},
#  'isabela arturo sanabria del valle': {'query': 'el presunto responsable violó el artículo 122 fracción xxii de la ley general de vida silvestre',
#   'score': 39},
#  'ind.rosalie-jacqueline larivière': {'query': 'el presunto responsable violó el artículo 122 fracción xxii de la ley general de vida silvestre',
#   'score': 39},
#  'lucas rousseau': {'query': 'such as profepa', 'score': 62},
#  'juliette-dorothée mercier': {'score': 59,
#   'query': 'the owner of the maderería'},
#  'anthony nguyen': {'query': 'anthony nguyen', 'score': 100},
#  'dorothy bradford': {'query': 'nardostachys grandiflora', 'score': 60},
#  'dr.victor dionne-larouche': {'score': 44,
#   'query': 'troy miller, director, field operations, new york field office'},
#  'dr.marguerite-hortense bolduc': {'score': 44,
#   'query': 'troy miller, director, field operations, new york field office'},
#  'carl hudson': {'score': 77, 'query': 'caleb m. hudson'},
#  'caleb mason': {'score': 77, 'query': 'caleb m. hudson'},
#  'dale hudson': {'score': 77, 'query': 'caleb m. hudson'},
#  'jeff le': {'score': 88, 'query': 'jeff lowe'},
#  'maría teresa prieto villaseñor': {'query': 'tater ortiz, port director, brownsville port of entry',
#   'score': 46},
#  'fan fei': {'query': 'san felipe', 'score': 71},
#  'wan fei': {'query': 'san felipe', 'score': 71},
#  'yan fei': {'query': 'san felipe', 'score': 71},
#  'dan fei': {'query': 'san felipe', 'score': 71},
#  'sun fei': {'query': 'san felipe', 'score': 71},
#  'sean le': {'query': 'san felipe', 'score': 71},
#  'pan fei': {'score': 40, 'query': 'pfm'},
#  'thomas-louis blanchette': {'query': 'customs arrests 52 people for buying illicit cigarettes',
#   'score': 44},
#  'thomas robitaille-fréchette': {'query': 'customs arrests 52 people for buying illicit cigarettes',
#   'score': 44},
#  'christelle-maryse charette': {'query': 'customs arrests 52 people for buying illicit cigarettes',
#   'score': 44},
#  'margarita josefina melgar puente': {'query': 'customs arrests 52 people for buying illicit cigarettes',
#   'score': 44},
#  'christiane-olivia charette': {'score': 44,
#   'query': 'customs smashes two mobile distribution centres of illicit cigarettes'},
#  'jonathan chartrand-arsenault': {'score': 49,
#   'query': 'contact information of wccb headquarters and regional offices'},
#  'richard wagner': {'query': 'richard zagger', 'score': 86},
#  'zhang long': {'score': 72, 'query': 'hai trung luong'},
#  'huang long': {'score': 72, 'query': 'hai trung luong'},
#  'dr.daniel spencer': {'score': 58, 'query': 'dueño de las especies.'},
#  'édouard-lucas desrosiers': {'score': 58, 'query': 'dueño de las especies.'},
#  'dr.denis desbiens': {'score': 58, 'query': 'dueño de las especies.'},
#  'dr.melanie spence': {'score': 58, 'query': 'dueño de las especies.'},
#  'sébastien-alexandre st-pierre': {'query': 'scientific name and key facts about the species',
#   'score': 47},
#  'christine marcotte-tessier': {'query': 'scientific name and key facts about the species',
#   'score': 47},
#  'jesus hill': {'query': 'jesús "h"', 'score': 67},
#  'jesse holt': {'query': 'jesús "h"', 'score': 67},
#  'jesse hall': {'query': 'jesús "h"', 'score': 67},
#  'mélanie desrosiers': {'query': 'manie du plessis', 'score': 71},
#  'jose winters': {'score': 56, 'query': 'oso “invictus”'},
#  'ross nichols': {'score': 56, 'query': 'oso “invictus”'},
#  'jose vincent': {'score': 56, 'query': 'oso “invictus”'},
#  'rose nichols': {'score': 56, 'query': 'oso “invictus”'},
#  'patrick sellers': {'score': 81, 'query': 'rick sellars'},
#  'troy franklin': {'query': 'troy fairbanks', 'score': 74},
#  'nicole tessier-provost': {'query': 'haile selassie, emperor of ethiopia',
#   'score': 53},
#  'gerasimova polina andreevna': {'query': 'petaluma police also contacted wang and trev',
#   'score': 51},
#  'joel hines': {'query': 'dolphins', 'score': 67},
#  'dou lin': {'query': 'dolphins', 'score': 67},
#  'brenda dennis': {'score': 65, 'query': 'obregonia denegrii'},
#  'regina dennis': {'score': 65, 'query': 'obregonia denegrii'},
#  'dr.ing. alonso adame': {'score': 48,
#   'query': 'dirty dining: wd-40 on dish rack, food kept'},
#  'donald spence': {'score': 73, 'query': 'donald joseph wiener'},
#  'daniel cole': {'query': 'daniel c. e.', 'score': 82},
#  'daniel rice': {'query': 'daniel c. e.', 'score': 82},
#  'daniel chen': {'query': 'daniel c. e.', 'score': 82},
#  'daniel pace': {'query': 'daniel c. e.', 'score': 82},
#  'lucas-william bilodeau': {'score': 58,
#   'query': 'cosma wilungula balongelwa'},
#  'robert burgess': {'score': 89, 'query': 'robert burgos'},
#  'rufino maría del carmen camacho brito': {'score': 26,
#   'query': 'baja california - the fishing prohibition in the gulf of santa clara and san felipe has led to protests from local fishermen who claim that they are not able to make a living due to the restrictions. on december 2nd'},
#  'william shelton': {'query': 'william sheldon', 'score': 93},
#  'he jian ping': {'score': 64, 'query': 'hk is a shopping'},
#  'hu xiao hong': {'score': 64, 'query': 'hk is a shopping'},
#  'he xiao hong': {'score': 64, 'query': 'hk is a shopping'},
#  'lisa hopkins': {'score': 64, 'query': 'hk is a shopping'},
#  'james conley': {'score': 92, 'query': 'james copley'},
#  'steven thomas': {'score': 96, 'query': 'steve thomas'},
#  'mario perez': {'score': 81, 'query': 'maurico m. perez'},
#  'edward martinez': {'query': 'eduardo ulises martinez', 'score': 74},
#  'dr.caroline martinez': {'query': 'eduardo ulises martinez', 'score': 74},
#  'norma arcelia quiñones garica': {'query': 'la información que proporcionaste no es un artículo de noticias',
#   'score': 46},
#  'groundsland': {'query': 'newfoundland', 'score': 70},
#  'nicole jensen': {'score': 65, 'query': 'municipio de ensenada'},
#  'joséphine germain-croteau': {'score': 57, 'query': 'topwin trading co ltd.'},
#  'renato andrés arellano': {'query': 'el presidente andrã©s manuel lã³pez obrador',
#   'score': 52},
#  'cristian luis manuel murillo preciado': {'query': 'se impuso como medida de seguridad el decomiso precautorio de los psitácidos.',
#   'score': 41},
#  'gloria marco antonio saucedo apodaca': {'score': 29,
#   'query': 'arizona seeing more pregnant mothers and newborns affected by opioid addiction. a phoenix nonprofit is a place for recovering moms and infants to detox and receive treatment.'},
#  'donald boone': {'score': 88, 'query': 'donald rooney'},
#  'mr. brian williams ii': {'query': "summary of wccb's efforts in combating wildlife crime",
#   'score': 46},
#  'joshua rangel': {'score': 69, 'query': 'josé luis rivas rangel'},
#  'dr.mark oconnor': {'score': 76, 'query': 'delmar connour'},
#  'alex prévost': {'query': 'mexpost', 'score': 63},
#  'phillip griffin': {'score': 73, 'query': 'steven phillip griffin, ii'},
#  'brad burns': {'score': 74, 'query': 'bad bunny'},
#  'bernardo ana luisa sauceda rangel': {'query': 'no hay nada que pueda extraer.',
#   'score': 55},
#  'felix orta': {'score': 74, 'query': 'felix kha'},
#  'ruth tran': {'query': 'thu thi tran', 'score': 76},
#  'guan juan': {'score': 74, 'query': 'guanajuato'},
#  'sr(a). ivonne delgadillo': {'query': 'such as "the proprietors" and "inspectors federals." additionally',
#   'score': 45},
#  'bai hao': {'query': 'búho', 'score': 55},
#  'susan choi': {'score': 73, 'query': 'sui fan chiu'},
#  'michael lozano': {'query': 'michael loo', 'score': 88},
#  'josé carlos matos': {'score': 59, 'query': 'dos ciudadanos mexicanos'},
#  'sergio de la garza ocampo': {'query': 'el responsable de la madera no acreditado',
#   'score': 55},
#  'elisa de anda cedillo': {'query': 'el responsable de la madera no acreditado',
#   'score': 55},
#  'anthony oneal': {'query': 'anton nel', 'score': 82},
#  'seth jefferson': {'query': 'thos. jefferson', 'score': 83},
#  'jose jefferson': {'query': 'thos. jefferson', 'score': 83},
#  'fernando abraham delgadillo cardenas': {'query': 'la información proporcionada no contiene nombres de personas o entidades que hayan sido arrestadas o plead guilty en relación con el tráfico ilegal de animales. por lo tanto',
#   'score': 29},
#  'mercedes rivas': {'query': 'echeveria sp.', 'score': 62},
#  'michelle arias': {'query': 'echeveria sp.', 'score': 62},
#  'karina ana maría rodrígez aponte': {'score': 45,
#   'query': 'y menciona a la procuraduría federal de protección al ambiente'},
#  'dr.maría josé dulce maría orozco cisneros': {'query': 'la mujer sorprendida con mil huevos de tortuga en el mercado de la viga es la imputada. el nombre de la mujer no se menciona explícitamente en el artículo',
#   'score': 31},
#  'steven wagner': {'score': 76, 'query': 'teenager'},
#  'natalia espartaco sisneros ochoa': {'query': 'samuel spencer, commissioner of the district of columbia',
#   'score': 45},
#  'homero castillo': {'score': 72, 'query': 'hermosillo'},
#  "tov. teterina ninel' vadimovna": {'score': 43,
#   'query': 'no puedo extraer ningún nombre de la información que me has proporcionado.'},
#  'joshua harvey': {'score': 100, 'query': 'joshua harvey'},
#  'joe ortiz': {'query': 'joe exotic', 'score': 74},
#  ...}

# %%
scraped = pd.read_csv('./traffic/incidents_scraped.csv')

# check articles
results = {}
for index, row in names.iterrows():
    hits = scraped[scraped['scrape_text'].str.contains(row['name'], case=False, na=False)]
    if not hits.empty:

        results[row['match']] = {}

        results[row['match']]['case_name'] = row['name']
        results[row['match']]['case_name_score'] = row['score']

        # context
        start_index = hits.iloc[0]['scrape_text'].lower().find(row['name'])
        start = max(start_index - 100, 0) 
        end = min(start_index + len(row['name']) + 100, len(hits.iloc[0]['scrape_text']))
        results[row['match']]['case_name_context'] = hits.iloc[0]['scrape_text'][start:end]

        results[row['match']]['sources'] = hits['Primary Source'].to_list()

# %%
with open('names_metadata.json', 'w') as file:
    json.dump(results, file, indent=4)

# %% [markdown]
# # Removing LE

# %%
# the context key in results provides a peek at 100 chars before and 100 chars after when the name was mentioned
# we went through these to make sure that the names were not of attorney generals, officers, etc
# though we tried to do this when sanitizing the LLM output, some names still slipped through

# DON'T RUN THIS CELL IF YOU DON'T WANT TO REMOVE THESE NAMES!


results_copy = results.copy()
for name in names_to_remove:
    try:
        del results_copy[name]

with open('names_metadata.json', 'w') as file:
    json.dump(results_copy, file, indent=4)
